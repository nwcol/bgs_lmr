# %% [raw]
# Computes total deleterious mutation rate ``U`` for each mutation
# model, element (DFE) class, and chromosome and saves them in
# `../data/U_tbl.csv`.

# %%
import numpy as np
import pandas

# %%
ccds_lof_deciles = [f"ccds_lof_d{i}" for i in range(1, 12)]
phastcons_bins = [f"phastcons_{(5*i)}-{5*(i+1)}" for i in range(16)]
elem_classes = ["ccds_merged", "promoters", "enhancers"] + ccds_lof_deciles + phastcons_bins
chroms = list(range(1, 23))
mut_models = ["carlson", "gnomad", "roulette"]

# %%
# Tabulate total deleterious mutation rates

cols = ["chrom", "mut_model", "elem_type", "U"]
data = []

for chrom in chroms:
    for mut_model in mut_models:
        mut_fname = f"../data/mutation_arrays/{mut_model}/{mut_model}_map_chr{chrom}.npy"
        mut_map = np.load(mut_fname)
        mut_map = np.ma.array(mut_map, mask=np.isnan(mut_map))

        for elem_class in elem_classes:
            # Different element types have slightly different filepaths
            # Merged CCDS
            if elem_class == "ccds_merged":
                annot_fname = f"../data/annotations/ccds/merged/ccds_merged_chr{chrom}.bed.gz"

            # CCDS LOF deciles
            elif elem_class in ccds_lof_deciles:
                x = elem_class.replace("ccds_", "")
                annot_fname = f"../data/annotations/ccds/{x}/{elem_class}_chr{chrom}.bed.gz"

            # Regulatory elements
            elif elem_class in ["promoters", "enhancers"]:
                annot_fname = f"../data/annotations/regulatory/{elem_class}/{elem_class}_chr{chrom}.bed.gz"

            # Non-coding phastCons elements
            elif elem_class in phastcons_bins:
                x = elem_class.replace("phastcons_", "")
                annot_fname = f"../data/annotations/phastcons/top{x}/phastcons_top{x}_chr{chrom}.bed.gz"

            else:
                raise ValueError("unknown element class")

            elements = bgshr.Util.read_bedfile(annot_fname)
            mask = bgshr.Util.elements_to_mask(elements, L=len(mut_map))
            n_sites = np.sum(mask == False)
            elem_mut_map = np.ma.array(mut_map, mask=mask)
            n_sites_masked = np.sum(elem_mut_map.mask == False)
            U = np.sum(elem_mut_map) * n_sites / n_sites_masked
            row = [
                chrom, 
                mut_model, 
                elem_class, 
                U
            ]
            data.append(row)
            print(chrom, mut_model, elem_class)

df = pandas.DataFrame(data, columns=cols)
df.to_csv("../data/U_tbl.csv", index=False)
# Out:
# 1 carlson ccds_merged
# 1 carlson promoters
# 1 carlson enhancers
# 1 carlson ccds_lof_d1
# 1 carlson ccds_lof_d2
# 1 carlson ccds_lof_d3
# 1 carlson ccds_lof_d4
# 1 carlson ccds_lof_d5
# 1 carlson ccds_lof_d6
# 1 carlson ccds_lof_d7
# 1 carlson ccds_lof_d8
# 1 carlson ccds_lof_d9
# 1 carlson ccds_lof_d10
# 1 carlson ccds_lof_d11
# 1 carlson phastcons_0-5
# 1 carlson phastcons_5-10
# 1 carlson phastcons_10-15
# 1 carlson phastcons_15-20
# 1 carlson phastcons_20-25
# 1 carlson phastcons_25-30
# 1 carlson phastcons_30-35
# 1 carlson phastcons_35-40
# 1 carlson phastcons_40-45
# 1 carlson phastcons_45-50
# 1 carlson phastcons_50-55
# 1 carlson phastcons_55-60
# 1 carlson phastcons_60-65
# 1 carlson phastcons_65-70
# 1 carlson phastcons_70-75
# 1 carlson phastcons_75-80
# 1 gnomad ccds_merged
# 1 gnomad promoters
# 1 gnomad enhancers
# 1 gnomad ccds_lof_d1
# 1 gnomad ccds_lof_d2
# 1 gnomad ccds_lof_d3
# 1 gnomad ccds_lof_d4
# 1 gnomad ccds_lof_d5
# 1 gnomad ccds_lof_d6
# 1 gnomad ccds_lof_d7
# 1 gnomad ccds_lof_d8
# 1 gnomad ccds_lof_d9
# 1 gnomad ccds_lof_d10
# 1 gnomad ccds_lof_d11
# 1 gnomad phastcons_0-5
# 1 gnomad phastcons_5-10
# 1 gnomad phastcons_10-15
# 1 gnomad phastcons_15-20
# 1 gnomad phastcons_20-25
# 1 gnomad phastcons_25-30
# 1 gnomad phastcons_30-35
# 1 gnomad phastcons_35-40
# 1 gnomad phastcons_40-45
# 1 gnomad phastcons_45-50
# 1 gnomad phastcons_50-55
# 1 gnomad phastcons_55-60
# 1 gnomad phastcons_60-65
# 1 gnomad phastcons_65-70
# 1 gnomad phastcons_70-75
# 1 gnomad phastcons_75-80
# 1 roulette ccds_merged
# 1 roulette promoters
# 1 roulette enhancers
# 1 roulette ccds_lof_d1
# 1 roulette ccds_lof_d2
# 1 roulette ccds_lof_d3
# 1 roulette ccds_lof_d4
# 1 roulette ccds_lof_d5
# 1 roulette ccds_lof_d6
# 1 roulette ccds_lof_d7
# 1 roulette ccds_lof_d8
# 1 roulette ccds_lof_d9
# 1 roulette ccds_lof_d10
# 1 roulette ccds_lof_d11
# 1 roulette phastcons_0-5
# 1 roulette phastcons_5-10
# 1 roulette phastcons_10-15
# 1 roulette phastcons_15-20
# 1 roulette phastcons_20-25
# 1 roulette phastcons_25-30
# 1 roulette phastcons_30-35
# 1 roulette phastcons_35-40
# 1 roulette phastcons_40-45
# 1 roulette phastcons_45-50
# 1 roulette phastcons_50-55
# 1 roulette phastcons_55-60
# 1 roulette phastcons_60-65
# 1 roulette phastcons_65-70
# 1 roulette phastcons_70-75
# 1 roulette phastcons_75-80
# 2 carlson ccds_merged
# 2 carlson promoters
# 2 carlson enhancers
# 2 carlson ccds_lof_d1
# 2 carlson ccds_lof_d2
# 2 carlson ccds_lof_d3
# 2 carlson ccds_lof_d4
# 2 carlson ccds_lof_d5
# 2 carlson ccds_lof_d6
# 2 carlson ccds_lof_d7
# 2 carlson ccds_lof_d8
# 2 carlson ccds_lof_d9
# 2 carlson ccds_lof_d10
# 2 carlson ccds_lof_d11
# 2 carlson phastcons_0-5
# 2 carlson phastcons_5-10
# 2 carlson phastcons_10-15
# 2 carlson phastcons_15-20
# 2 carlson phastcons_20-25
# 2 carlson phastcons_25-30
# 2 carlson phastcons_30-35
# 2 carlson phastcons_35-40
# 2 carlson phastcons_40-45
# 2 carlson phastcons_45-50
# 2 carlson phastcons_50-55
# 2 carlson phastcons_55-60
# 2 carlson phastcons_60-65
# 2 carlson phastcons_65-70
# 2 carlson phastcons_70-75
# 2 carlson phastcons_75-80
# 2 gnomad ccds_merged
# 2 gnomad promoters
# 2 gnomad enhancers
# 2 gnomad ccds_lof_d1
# 2 gnomad ccds_lof_d2
# 2 gnomad ccds_lof_d3
# 2 gnomad ccds_lof_d4
# 2 gnomad ccds_lof_d5
# 2 gnomad ccds_lof_d6
# 2 gnomad ccds_lof_d7
# 2 gnomad ccds_lof_d8
# 2 gnomad ccds_lof_d9
# 2 gnomad ccds_lof_d10
# 2 gnomad ccds_lof_d11
# 2 gnomad phastcons_0-5
# 2 gnomad phastcons_5-10
# 2 gnomad phastcons_10-15
# 2 gnomad phastcons_15-20
# 2 gnomad phastcons_20-25
# 2 gnomad phastcons_25-30
# 2 gnomad phastcons_30-35
# 2 gnomad phastcons_35-40
# 2 gnomad phastcons_40-45
# 2 gnomad phastcons_45-50
# 2 gnomad phastcons_50-55
# 2 gnomad phastcons_55-60
# 2 gnomad phastcons_60-65
# 2 gnomad phastcons_65-70
# 2 gnomad phastcons_70-75
# 2 gnomad phastcons_75-80
# 2 roulette ccds_merged
# 2 roulette promoters
# 2 roulette enhancers
# 2 roulette ccds_lof_d1
# 2 roulette ccds_lof_d2
# 2 roulette ccds_lof_d3
# 2 roulette ccds_lof_d4
# 2 roulette ccds_lof_d5
# 2 roulette ccds_lof_d6
# 2 roulette ccds_lof_d7
# 2 roulette ccds_lof_d8
# 2 roulette ccds_lof_d9
# 2 roulette ccds_lof_d10
# 2 roulette ccds_lof_d11
# 2 roulette phastcons_0-5
# 2 roulette phastcons_5-10
# 2 roulette phastcons_10-15
# 2 roulette phastcons_15-20
# 2 roulette phastcons_20-25
# 2 roulette phastcons_25-30
# 2 roulette phastcons_30-35
# 2 roulette phastcons_35-40
# 2 roulette phastcons_40-45
# 2 roulette phastcons_45-50
# 2 roulette phastcons_50-55
# 2 roulette phastcons_55-60
# 2 roulette phastcons_60-65
# 2 roulette phastcons_65-70
# 2 roulette phastcons_70-75
# 2 roulette phastcons_75-80
# 3 carlson ccds_merged
# 3 carlson promoters
# 3 carlson enhancers
# 3 carlson ccds_lof_d1
# 3 carlson ccds_lof_d2
# 3 carlson ccds_lof_d3
# 3 carlson ccds_lof_d4
# 3 carlson ccds_lof_d5
# 3 carlson ccds_lof_d6
# 3 carlson ccds_lof_d7
# 3 carlson ccds_lof_d8
# 3 carlson ccds_lof_d9
# 3 carlson ccds_lof_d10
# 3 carlson ccds_lof_d11
# 3 carlson phastcons_0-5
# 3 carlson phastcons_5-10
# 3 carlson phastcons_10-15
# 3 carlson phastcons_15-20
# 3 carlson phastcons_20-25
# 3 carlson phastcons_25-30
# 3 carlson phastcons_30-35
# 3 carlson phastcons_35-40
# 3 carlson phastcons_40-45
# 3 carlson phastcons_45-50
# 3 carlson phastcons_50-55
# 3 carlson phastcons_55-60
# 3 carlson phastcons_60-65
# 3 carlson phastcons_65-70
# 3 carlson phastcons_70-75
# 3 carlson phastcons_75-80
# 3 gnomad ccds_merged
# 3 gnomad promoters
# 3 gnomad enhancers
# 3 gnomad ccds_lof_d1
# 3 gnomad ccds_lof_d2
# 3 gnomad ccds_lof_d3
# 3 gnomad ccds_lof_d4
# 3 gnomad ccds_lof_d5
# 3 gnomad ccds_lof_d6
# 3 gnomad ccds_lof_d7
# 3 gnomad ccds_lof_d8
# 3 gnomad ccds_lof_d9
# 3 gnomad ccds_lof_d10
# 3 gnomad ccds_lof_d11
# 3 gnomad phastcons_0-5
# 3 gnomad phastcons_5-10
# 3 gnomad phastcons_10-15
# 3 gnomad phastcons_15-20
# 3 gnomad phastcons_20-25
# 3 gnomad phastcons_25-30
# 3 gnomad phastcons_30-35
# 3 gnomad phastcons_35-40
# 3 gnomad phastcons_40-45
# 3 gnomad phastcons_45-50
# 3 gnomad phastcons_50-55
# 3 gnomad phastcons_55-60
# 3 gnomad phastcons_60-65
# 3 gnomad phastcons_65-70
# 3 gnomad phastcons_70-75
# 3 gnomad phastcons_75-80
# 3 roulette ccds_merged
# 3 roulette promoters
# 3 roulette enhancers
# 3 roulette ccds_lof_d1
# 3 roulette ccds_lof_d2
# 3 roulette ccds_lof_d3
# 3 roulette ccds_lof_d4
# 3 roulette ccds_lof_d5
# 3 roulette ccds_lof_d6
# 3 roulette ccds_lof_d7
# 3 roulette ccds_lof_d8
# 3 roulette ccds_lof_d9
# 3 roulette ccds_lof_d10
# 3 roulette ccds_lof_d11
# 3 roulette phastcons_0-5
# 3 roulette phastcons_5-10
# 3 roulette phastcons_10-15
# 3 roulette phastcons_15-20
# 3 roulette phastcons_20-25
# 3 roulette phastcons_25-30
# 3 roulette phastcons_30-35
# 3 roulette phastcons_35-40
# 3 roulette phastcons_40-45
# 3 roulette phastcons_45-50
# 3 roulette phastcons_50-55
# 3 roulette phastcons_55-60
# 3 roulette phastcons_60-65
# 3 roulette phastcons_65-70
# 3 roulette phastcons_70-75
# 3 roulette phastcons_75-80
# 4 carlson ccds_merged
# 4 carlson promoters
# 4 carlson enhancers
# 4 carlson ccds_lof_d1
# 4 carlson ccds_lof_d2
# 4 carlson ccds_lof_d3
# 4 carlson ccds_lof_d4
# 4 carlson ccds_lof_d5
# 4 carlson ccds_lof_d6
# 4 carlson ccds_lof_d7
# 4 carlson ccds_lof_d8
# 4 carlson ccds_lof_d9
# 4 carlson ccds_lof_d10
# 4 carlson ccds_lof_d11
# 4 carlson phastcons_0-5
# 4 carlson phastcons_5-10
# 4 carlson phastcons_10-15
# 4 carlson phastcons_15-20
# 4 carlson phastcons_20-25
# 4 carlson phastcons_25-30
# 4 carlson phastcons_30-35
# 4 carlson phastcons_35-40
# 4 carlson phastcons_40-45
# 4 carlson phastcons_45-50
# 4 carlson phastcons_50-55
# 4 carlson phastcons_55-60
# 4 carlson phastcons_60-65
# 4 carlson phastcons_65-70
# 4 carlson phastcons_70-75
# 4 carlson phastcons_75-80
# 4 gnomad ccds_merged
# 4 gnomad promoters
# 4 gnomad enhancers
# 4 gnomad ccds_lof_d1
# 4 gnomad ccds_lof_d2
# 4 gnomad ccds_lof_d3
# 4 gnomad ccds_lof_d4
# 4 gnomad ccds_lof_d5
# 4 gnomad ccds_lof_d6
# 4 gnomad ccds_lof_d7
# 4 gnomad ccds_lof_d8
# 4 gnomad ccds_lof_d9
# 4 gnomad ccds_lof_d10
# 4 gnomad ccds_lof_d11
# 4 gnomad phastcons_0-5
# 4 gnomad phastcons_5-10
# 4 gnomad phastcons_10-15
# 4 gnomad phastcons_15-20
# 4 gnomad phastcons_20-25
# 4 gnomad phastcons_25-30
# 4 gnomad phastcons_30-35
# 4 gnomad phastcons_35-40
# 4 gnomad phastcons_40-45
# 4 gnomad phastcons_45-50
# 4 gnomad phastcons_50-55
# 4 gnomad phastcons_55-60
# 4 gnomad phastcons_60-65
# 4 gnomad phastcons_65-70
# 4 gnomad phastcons_70-75
# 4 gnomad phastcons_75-80
# 4 roulette ccds_merged
# 4 roulette promoters
# 4 roulette enhancers
# 4 roulette ccds_lof_d1
# 4 roulette ccds_lof_d2
# 4 roulette ccds_lof_d3
# 4 roulette ccds_lof_d4
# 4 roulette ccds_lof_d5
# 4 roulette ccds_lof_d6
# 4 roulette ccds_lof_d7
# 4 roulette ccds_lof_d8
# 4 roulette ccds_lof_d9
# 4 roulette ccds_lof_d10
# 4 roulette ccds_lof_d11
# 4 roulette phastcons_0-5
# 4 roulette phastcons_5-10
# 4 roulette phastcons_10-15
# 4 roulette phastcons_15-20
# 4 roulette phastcons_20-25
# 4 roulette phastcons_25-30
# 4 roulette phastcons_30-35
# 4 roulette phastcons_35-40
# 4 roulette phastcons_40-45
# 4 roulette phastcons_45-50
# 4 roulette phastcons_50-55
# 4 roulette phastcons_55-60
# 4 roulette phastcons_60-65
# 4 roulette phastcons_65-70
# 4 roulette phastcons_70-75
# 4 roulette phastcons_75-80
# 5 carlson ccds_merged
# 5 carlson promoters
# 5 carlson enhancers
# 5 carlson ccds_lof_d1
# 5 carlson ccds_lof_d2
# 5 carlson ccds_lof_d3
# 5 carlson ccds_lof_d4
# 5 carlson ccds_lof_d5
# 5 carlson ccds_lof_d6
# 5 carlson ccds_lof_d7
# 5 carlson ccds_lof_d8
# 5 carlson ccds_lof_d9
# 5 carlson ccds_lof_d10
# 5 carlson ccds_lof_d11
# 5 carlson phastcons_0-5
# 5 carlson phastcons_5-10
# 5 carlson phastcons_10-15
# 5 carlson phastcons_15-20
# 5 carlson phastcons_20-25
# 5 carlson phastcons_25-30
# 5 carlson phastcons_30-35
# 5 carlson phastcons_35-40
# 5 carlson phastcons_40-45
# 5 carlson phastcons_45-50
# 5 carlson phastcons_50-55
# 5 carlson phastcons_55-60
# 5 carlson phastcons_60-65
# 5 carlson phastcons_65-70
# 5 carlson phastcons_70-75
# 5 carlson phastcons_75-80
# 5 gnomad ccds_merged
# 5 gnomad promoters
# 5 gnomad enhancers
# 5 gnomad ccds_lof_d1
# 5 gnomad ccds_lof_d2
# 5 gnomad ccds_lof_d3
# 5 gnomad ccds_lof_d4
# 5 gnomad ccds_lof_d5
# 5 gnomad ccds_lof_d6
# 5 gnomad ccds_lof_d7
# 5 gnomad ccds_lof_d8
# 5 gnomad ccds_lof_d9
# 5 gnomad ccds_lof_d10
# 5 gnomad ccds_lof_d11
# 5 gnomad phastcons_0-5
# 5 gnomad phastcons_5-10
# 5 gnomad phastcons_10-15
# 5 gnomad phastcons_15-20
# 5 gnomad phastcons_20-25
# 5 gnomad phastcons_25-30
# 5 gnomad phastcons_30-35
# 5 gnomad phastcons_35-40
# 5 gnomad phastcons_40-45
# 5 gnomad phastcons_45-50
# 5 gnomad phastcons_50-55
# 5 gnomad phastcons_55-60
# 5 gnomad phastcons_60-65
# 5 gnomad phastcons_65-70
# 5 gnomad phastcons_70-75
# 5 gnomad phastcons_75-80
# 5 roulette ccds_merged
# 5 roulette promoters
# 5 roulette enhancers
# 5 roulette ccds_lof_d1
# 5 roulette ccds_lof_d2
# 5 roulette ccds_lof_d3
# 5 roulette ccds_lof_d4
# 5 roulette ccds_lof_d5
# 5 roulette ccds_lof_d6
# 5 roulette ccds_lof_d7
# 5 roulette ccds_lof_d8
# 5 roulette ccds_lof_d9
# 5 roulette ccds_lof_d10
# 5 roulette ccds_lof_d11
# 5 roulette phastcons_0-5
# 5 roulette phastcons_5-10
# 5 roulette phastcons_10-15
# 5 roulette phastcons_15-20
# 5 roulette phastcons_20-25
# 5 roulette phastcons_25-30
# 5 roulette phastcons_30-35
# 5 roulette phastcons_35-40
# 5 roulette phastcons_40-45
# 5 roulette phastcons_45-50
# 5 roulette phastcons_50-55
# 5 roulette phastcons_55-60
# 5 roulette phastcons_60-65
# 5 roulette phastcons_65-70
# 5 roulette phastcons_70-75
# 5 roulette phastcons_75-80
# 6 carlson ccds_merged
# 6 carlson promoters
# 6 carlson enhancers
# 6 carlson ccds_lof_d1
# 6 carlson ccds_lof_d2
# 6 carlson ccds_lof_d3
# 6 carlson ccds_lof_d4
# 6 carlson ccds_lof_d5
# 6 carlson ccds_lof_d6
# 6 carlson ccds_lof_d7
# 6 carlson ccds_lof_d8
# 6 carlson ccds_lof_d9
# 6 carlson ccds_lof_d10
# 6 carlson ccds_lof_d11
# 6 carlson phastcons_0-5
# 6 carlson phastcons_5-10
# 6 carlson phastcons_10-15
# 6 carlson phastcons_15-20
# 6 carlson phastcons_20-25
# 6 carlson phastcons_25-30
# 6 carlson phastcons_30-35
# 6 carlson phastcons_35-40
# 6 carlson phastcons_40-45
# 6 carlson phastcons_45-50
# 6 carlson phastcons_50-55
# 6 carlson phastcons_55-60
# 6 carlson phastcons_60-65
# 6 carlson phastcons_65-70
# 6 carlson phastcons_70-75
# 6 carlson phastcons_75-80
# 6 gnomad ccds_merged
# 6 gnomad promoters
# 6 gnomad enhancers
# 6 gnomad ccds_lof_d1
# 6 gnomad ccds_lof_d2
# 6 gnomad ccds_lof_d3
# 6 gnomad ccds_lof_d4
# 6 gnomad ccds_lof_d5
# 6 gnomad ccds_lof_d6
# 6 gnomad ccds_lof_d7
# 6 gnomad ccds_lof_d8
# 6 gnomad ccds_lof_d9
# 6 gnomad ccds_lof_d10
# 6 gnomad ccds_lof_d11
# 6 gnomad phastcons_0-5
# 6 gnomad phastcons_5-10
# 6 gnomad phastcons_10-15
# 6 gnomad phastcons_15-20
# 6 gnomad phastcons_20-25
# 6 gnomad phastcons_25-30
# 6 gnomad phastcons_30-35
# 6 gnomad phastcons_35-40
# 6 gnomad phastcons_40-45
# 6 gnomad phastcons_45-50
# 6 gnomad phastcons_50-55
# 6 gnomad phastcons_55-60
# 6 gnomad phastcons_60-65
# 6 gnomad phastcons_65-70
# 6 gnomad phastcons_70-75
# 6 gnomad phastcons_75-80
# 6 roulette ccds_merged
# 6 roulette promoters
# 6 roulette enhancers
# 6 roulette ccds_lof_d1
# 6 roulette ccds_lof_d2
# 6 roulette ccds_lof_d3
# 6 roulette ccds_lof_d4
# 6 roulette ccds_lof_d5
# 6 roulette ccds_lof_d6
# 6 roulette ccds_lof_d7
# 6 roulette ccds_lof_d8
# 6 roulette ccds_lof_d9
# 6 roulette ccds_lof_d10
# 6 roulette ccds_lof_d11
# 6 roulette phastcons_0-5
# 6 roulette phastcons_5-10
# 6 roulette phastcons_10-15
# 6 roulette phastcons_15-20
# 6 roulette phastcons_20-25
# 6 roulette phastcons_25-30
# 6 roulette phastcons_30-35
# 6 roulette phastcons_35-40
# 6 roulette phastcons_40-45
# 6 roulette phastcons_45-50
# 6 roulette phastcons_50-55
# 6 roulette phastcons_55-60
# 6 roulette phastcons_60-65
# 6 roulette phastcons_65-70
# 6 roulette phastcons_70-75
# 6 roulette phastcons_75-80
# 7 carlson ccds_merged
# 7 carlson promoters
# 7 carlson enhancers
# 7 carlson ccds_lof_d1
# 7 carlson ccds_lof_d2
# 7 carlson ccds_lof_d3
# 7 carlson ccds_lof_d4
# 7 carlson ccds_lof_d5
# 7 carlson ccds_lof_d6
# 7 carlson ccds_lof_d7
# 7 carlson ccds_lof_d8
# 7 carlson ccds_lof_d9
# 7 carlson ccds_lof_d10
# 7 carlson ccds_lof_d11
# 7 carlson phastcons_0-5
# 7 carlson phastcons_5-10
# 7 carlson phastcons_10-15
# 7 carlson phastcons_15-20
# 7 carlson phastcons_20-25
# 7 carlson phastcons_25-30
# 7 carlson phastcons_30-35
# 7 carlson phastcons_35-40
# 7 carlson phastcons_40-45
# 7 carlson phastcons_45-50
# 7 carlson phastcons_50-55
# 7 carlson phastcons_55-60
# 7 carlson phastcons_60-65
# 7 carlson phastcons_65-70
# 7 carlson phastcons_70-75
# 7 carlson phastcons_75-80
# 7 gnomad ccds_merged
# 7 gnomad promoters
# 7 gnomad enhancers
# 7 gnomad ccds_lof_d1
# 7 gnomad ccds_lof_d2
# 7 gnomad ccds_lof_d3
# 7 gnomad ccds_lof_d4
# 7 gnomad ccds_lof_d5
# 7 gnomad ccds_lof_d6
# 7 gnomad ccds_lof_d7
# 7 gnomad ccds_lof_d8
# 7 gnomad ccds_lof_d9
# 7 gnomad ccds_lof_d10
# 7 gnomad ccds_lof_d11
# 7 gnomad phastcons_0-5
# 7 gnomad phastcons_5-10
# 7 gnomad phastcons_10-15
# 7 gnomad phastcons_15-20
# 7 gnomad phastcons_20-25
# 7 gnomad phastcons_25-30
# 7 gnomad phastcons_30-35
# 7 gnomad phastcons_35-40
# 7 gnomad phastcons_40-45
# 7 gnomad phastcons_45-50
# 7 gnomad phastcons_50-55
# 7 gnomad phastcons_55-60
# 7 gnomad phastcons_60-65
# 7 gnomad phastcons_65-70
# 7 gnomad phastcons_70-75
# 7 gnomad phastcons_75-80
# 7 roulette ccds_merged
# 7 roulette promoters
# 7 roulette enhancers
# 7 roulette ccds_lof_d1
# 7 roulette ccds_lof_d2
# 7 roulette ccds_lof_d3
# 7 roulette ccds_lof_d4
# 7 roulette ccds_lof_d5
# 7 roulette ccds_lof_d6
# 7 roulette ccds_lof_d7
# 7 roulette ccds_lof_d8
# 7 roulette ccds_lof_d9
# 7 roulette ccds_lof_d10
# 7 roulette ccds_lof_d11
# 7 roulette phastcons_0-5
# 7 roulette phastcons_5-10
# 7 roulette phastcons_10-15
# 7 roulette phastcons_15-20
# 7 roulette phastcons_20-25
# 7 roulette phastcons_25-30
# 7 roulette phastcons_30-35
# 7 roulette phastcons_35-40
# 7 roulette phastcons_40-45
# 7 roulette phastcons_45-50
# 7 roulette phastcons_50-55
# 7 roulette phastcons_55-60
# 7 roulette phastcons_60-65
# 7 roulette phastcons_65-70
# 7 roulette phastcons_70-75
# 7 roulette phastcons_75-80
# 8 carlson ccds_merged
# 8 carlson promoters
# 8 carlson enhancers
# 8 carlson ccds_lof_d1
# 8 carlson ccds_lof_d2
# 8 carlson ccds_lof_d3
# 8 carlson ccds_lof_d4
# 8 carlson ccds_lof_d5
# 8 carlson ccds_lof_d6
# 8 carlson ccds_lof_d7
# 8 carlson ccds_lof_d8
# 8 carlson ccds_lof_d9
# 8 carlson ccds_lof_d10
# 8 carlson ccds_lof_d11
# 8 carlson phastcons_0-5
# 8 carlson phastcons_5-10
# 8 carlson phastcons_10-15
# 8 carlson phastcons_15-20
# 8 carlson phastcons_20-25
# 8 carlson phastcons_25-30
# 8 carlson phastcons_30-35
# 8 carlson phastcons_35-40
# 8 carlson phastcons_40-45
# 8 carlson phastcons_45-50
# 8 carlson phastcons_50-55
# 8 carlson phastcons_55-60
# 8 carlson phastcons_60-65
# 8 carlson phastcons_65-70
# 8 carlson phastcons_70-75
# 8 carlson phastcons_75-80
# 8 gnomad ccds_merged
# 8 gnomad promoters
# 8 gnomad enhancers
# 8 gnomad ccds_lof_d1
# 8 gnomad ccds_lof_d2
# 8 gnomad ccds_lof_d3
# 8 gnomad ccds_lof_d4
# 8 gnomad ccds_lof_d5
# 8 gnomad ccds_lof_d6
# 8 gnomad ccds_lof_d7
# 8 gnomad ccds_lof_d8
# 8 gnomad ccds_lof_d9
# 8 gnomad ccds_lof_d10
# 8 gnomad ccds_lof_d11
# 8 gnomad phastcons_0-5
# 8 gnomad phastcons_5-10
# 8 gnomad phastcons_10-15
# 8 gnomad phastcons_15-20
# 8 gnomad phastcons_20-25
# 8 gnomad phastcons_25-30
# 8 gnomad phastcons_30-35
# 8 gnomad phastcons_35-40
# 8 gnomad phastcons_40-45
# 8 gnomad phastcons_45-50
# 8 gnomad phastcons_50-55
# 8 gnomad phastcons_55-60
# 8 gnomad phastcons_60-65
# 8 gnomad phastcons_65-70
# 8 gnomad phastcons_70-75
# 8 gnomad phastcons_75-80
# 8 roulette ccds_merged
# 8 roulette promoters
# 8 roulette enhancers
# 8 roulette ccds_lof_d1
# 8 roulette ccds_lof_d2
# 8 roulette ccds_lof_d3
# 8 roulette ccds_lof_d4
# 8 roulette ccds_lof_d5
# 8 roulette ccds_lof_d6
# 8 roulette ccds_lof_d7
# 8 roulette ccds_lof_d8
# 8 roulette ccds_lof_d9
# 8 roulette ccds_lof_d10
# 8 roulette ccds_lof_d11
# 8 roulette phastcons_0-5
# 8 roulette phastcons_5-10
# 8 roulette phastcons_10-15
# 8 roulette phastcons_15-20
# 8 roulette phastcons_20-25
# 8 roulette phastcons_25-30
# 8 roulette phastcons_30-35
# 8 roulette phastcons_35-40
# 8 roulette phastcons_40-45
# 8 roulette phastcons_45-50
# 8 roulette phastcons_50-55
# 8 roulette phastcons_55-60
# 8 roulette phastcons_60-65
# 8 roulette phastcons_65-70
# 8 roulette phastcons_70-75
# 8 roulette phastcons_75-80
# 9 carlson ccds_merged
# 9 carlson promoters
# 9 carlson enhancers
# 9 carlson ccds_lof_d1
# 9 carlson ccds_lof_d2
# 9 carlson ccds_lof_d3
# 9 carlson ccds_lof_d4
# 9 carlson ccds_lof_d5
# 9 carlson ccds_lof_d6
# 9 carlson ccds_lof_d7
# 9 carlson ccds_lof_d8
# 9 carlson ccds_lof_d9
# 9 carlson ccds_lof_d10
# 9 carlson ccds_lof_d11
# 9 carlson phastcons_0-5
# 9 carlson phastcons_5-10
# 9 carlson phastcons_10-15
# 9 carlson phastcons_15-20
# 9 carlson phastcons_20-25
# 9 carlson phastcons_25-30
# 9 carlson phastcons_30-35
# 9 carlson phastcons_35-40
# 9 carlson phastcons_40-45
# 9 carlson phastcons_45-50
# 9 carlson phastcons_50-55
# 9 carlson phastcons_55-60
# 9 carlson phastcons_60-65
# 9 carlson phastcons_65-70
# 9 carlson phastcons_70-75
# 9 carlson phastcons_75-80
# 9 gnomad ccds_merged
# 9 gnomad promoters
# 9 gnomad enhancers
# 9 gnomad ccds_lof_d1
# 9 gnomad ccds_lof_d2
# 9 gnomad ccds_lof_d3
# 9 gnomad ccds_lof_d4
# 9 gnomad ccds_lof_d5
# 9 gnomad ccds_lof_d6
# 9 gnomad ccds_lof_d7
# 9 gnomad ccds_lof_d8
# 9 gnomad ccds_lof_d9
# 9 gnomad ccds_lof_d10
# 9 gnomad ccds_lof_d11
# 9 gnomad phastcons_0-5
# 9 gnomad phastcons_5-10
# 9 gnomad phastcons_10-15
# 9 gnomad phastcons_15-20
# 9 gnomad phastcons_20-25
# 9 gnomad phastcons_25-30
# 9 gnomad phastcons_30-35
# 9 gnomad phastcons_35-40
# 9 gnomad phastcons_40-45
# 9 gnomad phastcons_45-50
# 9 gnomad phastcons_50-55
# 9 gnomad phastcons_55-60
# 9 gnomad phastcons_60-65
# 9 gnomad phastcons_65-70
# 9 gnomad phastcons_70-75
# 9 gnomad phastcons_75-80
# 9 roulette ccds_merged
# 9 roulette promoters
# 9 roulette enhancers
# 9 roulette ccds_lof_d1
# 9 roulette ccds_lof_d2
# 9 roulette ccds_lof_d3
# 9 roulette ccds_lof_d4
# 9 roulette ccds_lof_d5
# 9 roulette ccds_lof_d6
# 9 roulette ccds_lof_d7
# 9 roulette ccds_lof_d8
# 9 roulette ccds_lof_d9
# 9 roulette ccds_lof_d10
# 9 roulette ccds_lof_d11
# 9 roulette phastcons_0-5
# 9 roulette phastcons_5-10
# 9 roulette phastcons_10-15
# 9 roulette phastcons_15-20
# 9 roulette phastcons_20-25
# 9 roulette phastcons_25-30
# 9 roulette phastcons_30-35
# 9 roulette phastcons_35-40
# 9 roulette phastcons_40-45
# 9 roulette phastcons_45-50
# 9 roulette phastcons_50-55
# 9 roulette phastcons_55-60
# 9 roulette phastcons_60-65
# 9 roulette phastcons_65-70
# 9 roulette phastcons_70-75
# 9 roulette phastcons_75-80
# 10 carlson ccds_merged
# 10 carlson promoters
# 10 carlson enhancers
# 10 carlson ccds_lof_d1
# 10 carlson ccds_lof_d2
# 10 carlson ccds_lof_d3
# 10 carlson ccds_lof_d4
# 10 carlson ccds_lof_d5
# 10 carlson ccds_lof_d6
# 10 carlson ccds_lof_d7
# 10 carlson ccds_lof_d8
# 10 carlson ccds_lof_d9
# 10 carlson ccds_lof_d10
# 10 carlson ccds_lof_d11
# 10 carlson phastcons_0-5
# 10 carlson phastcons_5-10
# 10 carlson phastcons_10-15
# 10 carlson phastcons_15-20
# 10 carlson phastcons_20-25
# 10 carlson phastcons_25-30
# 10 carlson phastcons_30-35
# 10 carlson phastcons_35-40
# 10 carlson phastcons_40-45
# 10 carlson phastcons_45-50
# 10 carlson phastcons_50-55
# 10 carlson phastcons_55-60
# 10 carlson phastcons_60-65
# 10 carlson phastcons_65-70
# 10 carlson phastcons_70-75
# 10 carlson phastcons_75-80
# 10 gnomad ccds_merged
# 10 gnomad promoters
# 10 gnomad enhancers
# 10 gnomad ccds_lof_d1
# 10 gnomad ccds_lof_d2
# 10 gnomad ccds_lof_d3
# 10 gnomad ccds_lof_d4
# 10 gnomad ccds_lof_d5
# 10 gnomad ccds_lof_d6
# 10 gnomad ccds_lof_d7
# 10 gnomad ccds_lof_d8
# 10 gnomad ccds_lof_d9
# 10 gnomad ccds_lof_d10
# 10 gnomad ccds_lof_d11
# 10 gnomad phastcons_0-5
# 10 gnomad phastcons_5-10
# 10 gnomad phastcons_10-15
# 10 gnomad phastcons_15-20
# 10 gnomad phastcons_20-25
# 10 gnomad phastcons_25-30
# 10 gnomad phastcons_30-35
# 10 gnomad phastcons_35-40
# 10 gnomad phastcons_40-45
# 10 gnomad phastcons_45-50
# 10 gnomad phastcons_50-55
# 10 gnomad phastcons_55-60
# 10 gnomad phastcons_60-65
# 10 gnomad phastcons_65-70
# 10 gnomad phastcons_70-75
# 10 gnomad phastcons_75-80
# 10 roulette ccds_merged
# 10 roulette promoters
# 10 roulette enhancers
# 10 roulette ccds_lof_d1
# 10 roulette ccds_lof_d2
# 10 roulette ccds_lof_d3
# 10 roulette ccds_lof_d4
# 10 roulette ccds_lof_d5
# 10 roulette ccds_lof_d6
# 10 roulette ccds_lof_d7
# 10 roulette ccds_lof_d8
# 10 roulette ccds_lof_d9
# 10 roulette ccds_lof_d10
# 10 roulette ccds_lof_d11
# 10 roulette phastcons_0-5
# 10 roulette phastcons_5-10
# 10 roulette phastcons_10-15
# 10 roulette phastcons_15-20
# 10 roulette phastcons_20-25
# 10 roulette phastcons_25-30
# 10 roulette phastcons_30-35
# 10 roulette phastcons_35-40
# 10 roulette phastcons_40-45
# 10 roulette phastcons_45-50
# 10 roulette phastcons_50-55
# 10 roulette phastcons_55-60
# 10 roulette phastcons_60-65
# 10 roulette phastcons_65-70
# 10 roulette phastcons_70-75
# 10 roulette phastcons_75-80
# 11 carlson ccds_merged
# 11 carlson promoters
# 11 carlson enhancers
# 11 carlson ccds_lof_d1
# 11 carlson ccds_lof_d2
# 11 carlson ccds_lof_d3
# 11 carlson ccds_lof_d4
# 11 carlson ccds_lof_d5
# 11 carlson ccds_lof_d6
# 11 carlson ccds_lof_d7
# 11 carlson ccds_lof_d8
# 11 carlson ccds_lof_d9
# 11 carlson ccds_lof_d10
# 11 carlson ccds_lof_d11
# 11 carlson phastcons_0-5
# 11 carlson phastcons_5-10
# 11 carlson phastcons_10-15
# 11 carlson phastcons_15-20
# 11 carlson phastcons_20-25
# 11 carlson phastcons_25-30
# 11 carlson phastcons_30-35
# 11 carlson phastcons_35-40
# 11 carlson phastcons_40-45
# 11 carlson phastcons_45-50
# 11 carlson phastcons_50-55
# 11 carlson phastcons_55-60
# 11 carlson phastcons_60-65
# 11 carlson phastcons_65-70
# 11 carlson phastcons_70-75
# 11 carlson phastcons_75-80
# 11 gnomad ccds_merged
# 11 gnomad promoters
# 11 gnomad enhancers
# 11 gnomad ccds_lof_d1
# 11 gnomad ccds_lof_d2
# 11 gnomad ccds_lof_d3
# 11 gnomad ccds_lof_d4
# 11 gnomad ccds_lof_d5
# 11 gnomad ccds_lof_d6
# 11 gnomad ccds_lof_d7
# 11 gnomad ccds_lof_d8
# 11 gnomad ccds_lof_d9
# 11 gnomad ccds_lof_d10
# 11 gnomad ccds_lof_d11
# 11 gnomad phastcons_0-5
# 11 gnomad phastcons_5-10
# 11 gnomad phastcons_10-15
# 11 gnomad phastcons_15-20
# 11 gnomad phastcons_20-25
# 11 gnomad phastcons_25-30
# 11 gnomad phastcons_30-35
# 11 gnomad phastcons_35-40
# 11 gnomad phastcons_40-45
# 11 gnomad phastcons_45-50
# 11 gnomad phastcons_50-55
# 11 gnomad phastcons_55-60
# 11 gnomad phastcons_60-65
# 11 gnomad phastcons_65-70
# 11 gnomad phastcons_70-75
# 11 gnomad phastcons_75-80
# 11 roulette ccds_merged
# 11 roulette promoters
# 11 roulette enhancers
# 11 roulette ccds_lof_d1
# 11 roulette ccds_lof_d2
# 11 roulette ccds_lof_d3
# 11 roulette ccds_lof_d4
# 11 roulette ccds_lof_d5
# 11 roulette ccds_lof_d6
# 11 roulette ccds_lof_d7
# 11 roulette ccds_lof_d8
# 11 roulette ccds_lof_d9
# 11 roulette ccds_lof_d10
# 11 roulette ccds_lof_d11
# 11 roulette phastcons_0-5
# 11 roulette phastcons_5-10
# 11 roulette phastcons_10-15
# 11 roulette phastcons_15-20
# 11 roulette phastcons_20-25
# 11 roulette phastcons_25-30
# 11 roulette phastcons_30-35
# 11 roulette phastcons_35-40
# 11 roulette phastcons_40-45
# 11 roulette phastcons_45-50
# 11 roulette phastcons_50-55
# 11 roulette phastcons_55-60
# 11 roulette phastcons_60-65
# 11 roulette phastcons_65-70
# 11 roulette phastcons_70-75
# 11 roulette phastcons_75-80
# 12 carlson ccds_merged
# 12 carlson promoters
# 12 carlson enhancers
# 12 carlson ccds_lof_d1
# 12 carlson ccds_lof_d2
# 12 carlson ccds_lof_d3
# 12 carlson ccds_lof_d4
# 12 carlson ccds_lof_d5
# 12 carlson ccds_lof_d6
# 12 carlson ccds_lof_d7
# 12 carlson ccds_lof_d8
# 12 carlson ccds_lof_d9
# 12 carlson ccds_lof_d10
# 12 carlson ccds_lof_d11
# 12 carlson phastcons_0-5
# 12 carlson phastcons_5-10
# 12 carlson phastcons_10-15
# 12 carlson phastcons_15-20
# 12 carlson phastcons_20-25
# 12 carlson phastcons_25-30
# 12 carlson phastcons_30-35
# 12 carlson phastcons_35-40
# 12 carlson phastcons_40-45
# 12 carlson phastcons_45-50
# 12 carlson phastcons_50-55
# 12 carlson phastcons_55-60
# 12 carlson phastcons_60-65
# 12 carlson phastcons_65-70
# 12 carlson phastcons_70-75
# 12 carlson phastcons_75-80
# 12 gnomad ccds_merged
# 12 gnomad promoters
# 12 gnomad enhancers
# 12 gnomad ccds_lof_d1
# 12 gnomad ccds_lof_d2
# 12 gnomad ccds_lof_d3
# 12 gnomad ccds_lof_d4
# 12 gnomad ccds_lof_d5
# 12 gnomad ccds_lof_d6
# 12 gnomad ccds_lof_d7
# 12 gnomad ccds_lof_d8
# 12 gnomad ccds_lof_d9
# 12 gnomad ccds_lof_d10
# 12 gnomad ccds_lof_d11
# 12 gnomad phastcons_0-5
# 12 gnomad phastcons_5-10
# 12 gnomad phastcons_10-15
# 12 gnomad phastcons_15-20
# 12 gnomad phastcons_20-25
# 12 gnomad phastcons_25-30
# 12 gnomad phastcons_30-35
# 12 gnomad phastcons_35-40
# 12 gnomad phastcons_40-45
# 12 gnomad phastcons_45-50
# 12 gnomad phastcons_50-55
# 12 gnomad phastcons_55-60
# 12 gnomad phastcons_60-65
# 12 gnomad phastcons_65-70
# 12 gnomad phastcons_70-75
# 12 gnomad phastcons_75-80
# 12 roulette ccds_merged
# 12 roulette promoters
# 12 roulette enhancers
# 12 roulette ccds_lof_d1
# 12 roulette ccds_lof_d2
# 12 roulette ccds_lof_d3
# 12 roulette ccds_lof_d4
# 12 roulette ccds_lof_d5
# 12 roulette ccds_lof_d6
# 12 roulette ccds_lof_d7
# 12 roulette ccds_lof_d8
# 12 roulette ccds_lof_d9
# 12 roulette ccds_lof_d10
# 12 roulette ccds_lof_d11
# 12 roulette phastcons_0-5
# 12 roulette phastcons_5-10
# 12 roulette phastcons_10-15
# 12 roulette phastcons_15-20
# 12 roulette phastcons_20-25
# 12 roulette phastcons_25-30
# 12 roulette phastcons_30-35
# 12 roulette phastcons_35-40
# 12 roulette phastcons_40-45
# 12 roulette phastcons_45-50
# 12 roulette phastcons_50-55
# 12 roulette phastcons_55-60
# 12 roulette phastcons_60-65
# 12 roulette phastcons_65-70
# 12 roulette phastcons_70-75
# 12 roulette phastcons_75-80
# 13 carlson ccds_merged
# 13 carlson promoters
# 13 carlson enhancers
# 13 carlson ccds_lof_d1
# 13 carlson ccds_lof_d2
# 13 carlson ccds_lof_d3
# 13 carlson ccds_lof_d4
# 13 carlson ccds_lof_d5
# 13 carlson ccds_lof_d6
# 13 carlson ccds_lof_d7
# 13 carlson ccds_lof_d8
# 13 carlson ccds_lof_d9
# 13 carlson ccds_lof_d10
# 13 carlson ccds_lof_d11
# 13 carlson phastcons_0-5
# 13 carlson phastcons_5-10
# 13 carlson phastcons_10-15
# 13 carlson phastcons_15-20
# 13 carlson phastcons_20-25
# 13 carlson phastcons_25-30
# 13 carlson phastcons_30-35
# 13 carlson phastcons_35-40
# 13 carlson phastcons_40-45
# 13 carlson phastcons_45-50
# 13 carlson phastcons_50-55
# 13 carlson phastcons_55-60
# 13 carlson phastcons_60-65
# 13 carlson phastcons_65-70
# 13 carlson phastcons_70-75
# 13 carlson phastcons_75-80
# 13 gnomad ccds_merged
# 13 gnomad promoters
# 13 gnomad enhancers
# 13 gnomad ccds_lof_d1
# 13 gnomad ccds_lof_d2
# 13 gnomad ccds_lof_d3
# 13 gnomad ccds_lof_d4
# 13 gnomad ccds_lof_d5
# 13 gnomad ccds_lof_d6
# 13 gnomad ccds_lof_d7
# 13 gnomad ccds_lof_d8
# 13 gnomad ccds_lof_d9
# 13 gnomad ccds_lof_d10
# 13 gnomad ccds_lof_d11
# 13 gnomad phastcons_0-5
# 13 gnomad phastcons_5-10
# 13 gnomad phastcons_10-15
# 13 gnomad phastcons_15-20
# 13 gnomad phastcons_20-25
# 13 gnomad phastcons_25-30
# 13 gnomad phastcons_30-35
# 13 gnomad phastcons_35-40
# 13 gnomad phastcons_40-45
# 13 gnomad phastcons_45-50
# 13 gnomad phastcons_50-55
# 13 gnomad phastcons_55-60
# 13 gnomad phastcons_60-65
# 13 gnomad phastcons_65-70
# 13 gnomad phastcons_70-75
# 13 gnomad phastcons_75-80
# 13 roulette ccds_merged
# 13 roulette promoters
# 13 roulette enhancers
# 13 roulette ccds_lof_d1
# 13 roulette ccds_lof_d2
# 13 roulette ccds_lof_d3
# 13 roulette ccds_lof_d4
# 13 roulette ccds_lof_d5
# 13 roulette ccds_lof_d6
# 13 roulette ccds_lof_d7
# 13 roulette ccds_lof_d8
# 13 roulette ccds_lof_d9
# 13 roulette ccds_lof_d10
# 13 roulette ccds_lof_d11
# 13 roulette phastcons_0-5
# 13 roulette phastcons_5-10
# 13 roulette phastcons_10-15
# 13 roulette phastcons_15-20
# 13 roulette phastcons_20-25
# 13 roulette phastcons_25-30
# 13 roulette phastcons_30-35
# 13 roulette phastcons_35-40
# 13 roulette phastcons_40-45
# 13 roulette phastcons_45-50
# 13 roulette phastcons_50-55
# 13 roulette phastcons_55-60
# 13 roulette phastcons_60-65
# 13 roulette phastcons_65-70
# 13 roulette phastcons_70-75
# 13 roulette phastcons_75-80
# 14 carlson ccds_merged
# 14 carlson promoters
# 14 carlson enhancers
# 14 carlson ccds_lof_d1
# 14 carlson ccds_lof_d2
# 14 carlson ccds_lof_d3
# 14 carlson ccds_lof_d4
# 14 carlson ccds_lof_d5
# 14 carlson ccds_lof_d6
# 14 carlson ccds_lof_d7
# 14 carlson ccds_lof_d8
# 14 carlson ccds_lof_d9
# 14 carlson ccds_lof_d10
# 14 carlson ccds_lof_d11
# 14 carlson phastcons_0-5
# 14 carlson phastcons_5-10
# 14 carlson phastcons_10-15
# 14 carlson phastcons_15-20
# 14 carlson phastcons_20-25
# 14 carlson phastcons_25-30
# 14 carlson phastcons_30-35
# 14 carlson phastcons_35-40
# 14 carlson phastcons_40-45
# 14 carlson phastcons_45-50
# 14 carlson phastcons_50-55
# 14 carlson phastcons_55-60
# 14 carlson phastcons_60-65
# 14 carlson phastcons_65-70
# 14 carlson phastcons_70-75
# 14 carlson phastcons_75-80
# 14 gnomad ccds_merged
# 14 gnomad promoters
# 14 gnomad enhancers
# 14 gnomad ccds_lof_d1
# 14 gnomad ccds_lof_d2
# 14 gnomad ccds_lof_d3
# 14 gnomad ccds_lof_d4
# 14 gnomad ccds_lof_d5
# 14 gnomad ccds_lof_d6
# 14 gnomad ccds_lof_d7
# 14 gnomad ccds_lof_d8
# 14 gnomad ccds_lof_d9
# 14 gnomad ccds_lof_d10
# 14 gnomad ccds_lof_d11
# 14 gnomad phastcons_0-5
# 14 gnomad phastcons_5-10
# 14 gnomad phastcons_10-15
# 14 gnomad phastcons_15-20
# 14 gnomad phastcons_20-25
# 14 gnomad phastcons_25-30
# 14 gnomad phastcons_30-35
# 14 gnomad phastcons_35-40
# 14 gnomad phastcons_40-45
# 14 gnomad phastcons_45-50
# 14 gnomad phastcons_50-55
# 14 gnomad phastcons_55-60
# 14 gnomad phastcons_60-65
# 14 gnomad phastcons_65-70
# 14 gnomad phastcons_70-75
# 14 gnomad phastcons_75-80
# 14 roulette ccds_merged
# 14 roulette promoters
# 14 roulette enhancers
# 14 roulette ccds_lof_d1
# 14 roulette ccds_lof_d2
# 14 roulette ccds_lof_d3
# 14 roulette ccds_lof_d4
# 14 roulette ccds_lof_d5
# 14 roulette ccds_lof_d6
# 14 roulette ccds_lof_d7
# 14 roulette ccds_lof_d8
# 14 roulette ccds_lof_d9
# 14 roulette ccds_lof_d10
# 14 roulette ccds_lof_d11
# 14 roulette phastcons_0-5
# 14 roulette phastcons_5-10
# 14 roulette phastcons_10-15
# 14 roulette phastcons_15-20
# 14 roulette phastcons_20-25
# 14 roulette phastcons_25-30
# 14 roulette phastcons_30-35
# 14 roulette phastcons_35-40
# 14 roulette phastcons_40-45
# 14 roulette phastcons_45-50
# 14 roulette phastcons_50-55
# 14 roulette phastcons_55-60
# 14 roulette phastcons_60-65
# 14 roulette phastcons_65-70
# 14 roulette phastcons_70-75
# 14 roulette phastcons_75-80
# 15 carlson ccds_merged
# 15 carlson promoters
# 15 carlson enhancers
# 15 carlson ccds_lof_d1
# 15 carlson ccds_lof_d2
# 15 carlson ccds_lof_d3
# 15 carlson ccds_lof_d4
# 15 carlson ccds_lof_d5
# 15 carlson ccds_lof_d6
# 15 carlson ccds_lof_d7
# 15 carlson ccds_lof_d8
# 15 carlson ccds_lof_d9
# 15 carlson ccds_lof_d10
# 15 carlson ccds_lof_d11
# 15 carlson phastcons_0-5
# 15 carlson phastcons_5-10
# 15 carlson phastcons_10-15
# 15 carlson phastcons_15-20
# 15 carlson phastcons_20-25
# 15 carlson phastcons_25-30
# 15 carlson phastcons_30-35
# 15 carlson phastcons_35-40
# 15 carlson phastcons_40-45
# 15 carlson phastcons_45-50
# 15 carlson phastcons_50-55
# 15 carlson phastcons_55-60
# 15 carlson phastcons_60-65
# 15 carlson phastcons_65-70
# 15 carlson phastcons_70-75
# 15 carlson phastcons_75-80
# 15 gnomad ccds_merged
# 15 gnomad promoters
# 15 gnomad enhancers
# 15 gnomad ccds_lof_d1
# 15 gnomad ccds_lof_d2
# 15 gnomad ccds_lof_d3
# 15 gnomad ccds_lof_d4
# 15 gnomad ccds_lof_d5
# 15 gnomad ccds_lof_d6
# 15 gnomad ccds_lof_d7
# 15 gnomad ccds_lof_d8
# 15 gnomad ccds_lof_d9
# 15 gnomad ccds_lof_d10
# 15 gnomad ccds_lof_d11
# 15 gnomad phastcons_0-5
# 15 gnomad phastcons_5-10
# 15 gnomad phastcons_10-15
# 15 gnomad phastcons_15-20
# 15 gnomad phastcons_20-25
# 15 gnomad phastcons_25-30
# 15 gnomad phastcons_30-35
# 15 gnomad phastcons_35-40
# 15 gnomad phastcons_40-45
# 15 gnomad phastcons_45-50
# 15 gnomad phastcons_50-55
# 15 gnomad phastcons_55-60
# 15 gnomad phastcons_60-65
# 15 gnomad phastcons_65-70
# 15 gnomad phastcons_70-75
# 15 gnomad phastcons_75-80
# 15 roulette ccds_merged
# 15 roulette promoters
# 15 roulette enhancers
# 15 roulette ccds_lof_d1
# 15 roulette ccds_lof_d2
# 15 roulette ccds_lof_d3
# 15 roulette ccds_lof_d4
# 15 roulette ccds_lof_d5
# 15 roulette ccds_lof_d6
# 15 roulette ccds_lof_d7
# 15 roulette ccds_lof_d8
# 15 roulette ccds_lof_d9
# 15 roulette ccds_lof_d10
# 15 roulette ccds_lof_d11
# 15 roulette phastcons_0-5
# 15 roulette phastcons_5-10
# 15 roulette phastcons_10-15
# 15 roulette phastcons_15-20
# 15 roulette phastcons_20-25
# 15 roulette phastcons_25-30
# 15 roulette phastcons_30-35
# 15 roulette phastcons_35-40
# 15 roulette phastcons_40-45
# 15 roulette phastcons_45-50
# 15 roulette phastcons_50-55
# 15 roulette phastcons_55-60
# 15 roulette phastcons_60-65
# 15 roulette phastcons_65-70
# 15 roulette phastcons_70-75
# 15 roulette phastcons_75-80
# 16 carlson ccds_merged
# 16 carlson promoters
# 16 carlson enhancers
# 16 carlson ccds_lof_d1
# 16 carlson ccds_lof_d2
# 16 carlson ccds_lof_d3
# 16 carlson ccds_lof_d4
# 16 carlson ccds_lof_d5
# 16 carlson ccds_lof_d6
# 16 carlson ccds_lof_d7
# 16 carlson ccds_lof_d8
# 16 carlson ccds_lof_d9
# 16 carlson ccds_lof_d10
# 16 carlson ccds_lof_d11
# 16 carlson phastcons_0-5
# 16 carlson phastcons_5-10
# 16 carlson phastcons_10-15
# 16 carlson phastcons_15-20
# 16 carlson phastcons_20-25
# 16 carlson phastcons_25-30
# 16 carlson phastcons_30-35
# 16 carlson phastcons_35-40
# 16 carlson phastcons_40-45
# 16 carlson phastcons_45-50
# 16 carlson phastcons_50-55
# 16 carlson phastcons_55-60
# 16 carlson phastcons_60-65
# 16 carlson phastcons_65-70
# 16 carlson phastcons_70-75
# 16 carlson phastcons_75-80
# 16 gnomad ccds_merged
# 16 gnomad promoters
# 16 gnomad enhancers
# 16 gnomad ccds_lof_d1
# 16 gnomad ccds_lof_d2
# 16 gnomad ccds_lof_d3
# 16 gnomad ccds_lof_d4
# 16 gnomad ccds_lof_d5
# 16 gnomad ccds_lof_d6
# 16 gnomad ccds_lof_d7
# 16 gnomad ccds_lof_d8
# 16 gnomad ccds_lof_d9
# 16 gnomad ccds_lof_d10
# 16 gnomad ccds_lof_d11
# 16 gnomad phastcons_0-5
# 16 gnomad phastcons_5-10
# 16 gnomad phastcons_10-15
# 16 gnomad phastcons_15-20
# 16 gnomad phastcons_20-25
# 16 gnomad phastcons_25-30
# 16 gnomad phastcons_30-35
# 16 gnomad phastcons_35-40
# 16 gnomad phastcons_40-45
# 16 gnomad phastcons_45-50
# 16 gnomad phastcons_50-55
# 16 gnomad phastcons_55-60
# 16 gnomad phastcons_60-65
# 16 gnomad phastcons_65-70
# 16 gnomad phastcons_70-75
# 16 gnomad phastcons_75-80
# 16 roulette ccds_merged
# 16 roulette promoters
# 16 roulette enhancers
# 16 roulette ccds_lof_d1
# 16 roulette ccds_lof_d2
# 16 roulette ccds_lof_d3
# 16 roulette ccds_lof_d4
# 16 roulette ccds_lof_d5
# 16 roulette ccds_lof_d6
# 16 roulette ccds_lof_d7
# 16 roulette ccds_lof_d8
# 16 roulette ccds_lof_d9
# 16 roulette ccds_lof_d10
# 16 roulette ccds_lof_d11
# 16 roulette phastcons_0-5
# 16 roulette phastcons_5-10
# 16 roulette phastcons_10-15
# 16 roulette phastcons_15-20
# 16 roulette phastcons_20-25
# 16 roulette phastcons_25-30
# 16 roulette phastcons_30-35
# 16 roulette phastcons_35-40
# 16 roulette phastcons_40-45
# 16 roulette phastcons_45-50
# 16 roulette phastcons_50-55
# 16 roulette phastcons_55-60
# 16 roulette phastcons_60-65
# 16 roulette phastcons_65-70
# 16 roulette phastcons_70-75
# 16 roulette phastcons_75-80
# 17 carlson ccds_merged
# 17 carlson promoters
# 17 carlson enhancers
# 17 carlson ccds_lof_d1
# 17 carlson ccds_lof_d2
# 17 carlson ccds_lof_d3
# 17 carlson ccds_lof_d4
# 17 carlson ccds_lof_d5
# 17 carlson ccds_lof_d6
# 17 carlson ccds_lof_d7
# 17 carlson ccds_lof_d8
# 17 carlson ccds_lof_d9
# 17 carlson ccds_lof_d10
# 17 carlson ccds_lof_d11
# 17 carlson phastcons_0-5
# 17 carlson phastcons_5-10
# 17 carlson phastcons_10-15
# 17 carlson phastcons_15-20
# 17 carlson phastcons_20-25
# 17 carlson phastcons_25-30
# 17 carlson phastcons_30-35
# 17 carlson phastcons_35-40
# 17 carlson phastcons_40-45
# 17 carlson phastcons_45-50
# 17 carlson phastcons_50-55
# 17 carlson phastcons_55-60
# 17 carlson phastcons_60-65
# 17 carlson phastcons_65-70
# 17 carlson phastcons_70-75
# 17 carlson phastcons_75-80
# 17 gnomad ccds_merged
# 17 gnomad promoters
# 17 gnomad enhancers
# 17 gnomad ccds_lof_d1
# 17 gnomad ccds_lof_d2
# 17 gnomad ccds_lof_d3
# 17 gnomad ccds_lof_d4
# 17 gnomad ccds_lof_d5
# 17 gnomad ccds_lof_d6
# 17 gnomad ccds_lof_d7
# 17 gnomad ccds_lof_d8
# 17 gnomad ccds_lof_d9
# 17 gnomad ccds_lof_d10
# 17 gnomad ccds_lof_d11
# 17 gnomad phastcons_0-5
# 17 gnomad phastcons_5-10
# 17 gnomad phastcons_10-15
# 17 gnomad phastcons_15-20
# 17 gnomad phastcons_20-25
# 17 gnomad phastcons_25-30
# 17 gnomad phastcons_30-35
# 17 gnomad phastcons_35-40
# 17 gnomad phastcons_40-45
# 17 gnomad phastcons_45-50
# 17 gnomad phastcons_50-55
# 17 gnomad phastcons_55-60
# 17 gnomad phastcons_60-65
# 17 gnomad phastcons_65-70
# 17 gnomad phastcons_70-75
# 17 gnomad phastcons_75-80
# 17 roulette ccds_merged
# 17 roulette promoters
# 17 roulette enhancers
# 17 roulette ccds_lof_d1
# 17 roulette ccds_lof_d2
# 17 roulette ccds_lof_d3
# 17 roulette ccds_lof_d4
# 17 roulette ccds_lof_d5
# 17 roulette ccds_lof_d6
# 17 roulette ccds_lof_d7
# 17 roulette ccds_lof_d8
# 17 roulette ccds_lof_d9
# 17 roulette ccds_lof_d10
# 17 roulette ccds_lof_d11
# 17 roulette phastcons_0-5
# 17 roulette phastcons_5-10
# 17 roulette phastcons_10-15
# 17 roulette phastcons_15-20
# 17 roulette phastcons_20-25
# 17 roulette phastcons_25-30
# 17 roulette phastcons_30-35
# 17 roulette phastcons_35-40
# 17 roulette phastcons_40-45
# 17 roulette phastcons_45-50
# 17 roulette phastcons_50-55
# 17 roulette phastcons_55-60
# 17 roulette phastcons_60-65
# 17 roulette phastcons_65-70
# 17 roulette phastcons_70-75
# 17 roulette phastcons_75-80
# 18 carlson ccds_merged
# 18 carlson promoters
# 18 carlson enhancers
# 18 carlson ccds_lof_d1
# 18 carlson ccds_lof_d2
# 18 carlson ccds_lof_d3
# 18 carlson ccds_lof_d4
# 18 carlson ccds_lof_d5
# 18 carlson ccds_lof_d6
# 18 carlson ccds_lof_d7
# 18 carlson ccds_lof_d8
# 18 carlson ccds_lof_d9
# 18 carlson ccds_lof_d10
# 18 carlson ccds_lof_d11
# 18 carlson phastcons_0-5
# 18 carlson phastcons_5-10
# 18 carlson phastcons_10-15
# 18 carlson phastcons_15-20
# 18 carlson phastcons_20-25
# 18 carlson phastcons_25-30
# 18 carlson phastcons_30-35
# 18 carlson phastcons_35-40
# 18 carlson phastcons_40-45
# 18 carlson phastcons_45-50
# 18 carlson phastcons_50-55
# 18 carlson phastcons_55-60
# 18 carlson phastcons_60-65
# 18 carlson phastcons_65-70
# 18 carlson phastcons_70-75
# 18 carlson phastcons_75-80
# 18 gnomad ccds_merged
# 18 gnomad promoters
# 18 gnomad enhancers
# 18 gnomad ccds_lof_d1
# 18 gnomad ccds_lof_d2
# 18 gnomad ccds_lof_d3
# 18 gnomad ccds_lof_d4
# 18 gnomad ccds_lof_d5
# 18 gnomad ccds_lof_d6
# 18 gnomad ccds_lof_d7
# 18 gnomad ccds_lof_d8
# 18 gnomad ccds_lof_d9
# 18 gnomad ccds_lof_d10
# 18 gnomad ccds_lof_d11
# 18 gnomad phastcons_0-5
# 18 gnomad phastcons_5-10
# 18 gnomad phastcons_10-15
# 18 gnomad phastcons_15-20
# 18 gnomad phastcons_20-25
# 18 gnomad phastcons_25-30
# 18 gnomad phastcons_30-35
# 18 gnomad phastcons_35-40
# 18 gnomad phastcons_40-45
# 18 gnomad phastcons_45-50
# 18 gnomad phastcons_50-55
# 18 gnomad phastcons_55-60
# 18 gnomad phastcons_60-65
# 18 gnomad phastcons_65-70
# 18 gnomad phastcons_70-75
# 18 gnomad phastcons_75-80
# 18 roulette ccds_merged
# 18 roulette promoters
# 18 roulette enhancers
# 18 roulette ccds_lof_d1
# 18 roulette ccds_lof_d2
# 18 roulette ccds_lof_d3
# 18 roulette ccds_lof_d4
# 18 roulette ccds_lof_d5
# 18 roulette ccds_lof_d6
# 18 roulette ccds_lof_d7
# 18 roulette ccds_lof_d8
# 18 roulette ccds_lof_d9
# 18 roulette ccds_lof_d10
# 18 roulette ccds_lof_d11
# 18 roulette phastcons_0-5
# 18 roulette phastcons_5-10
# 18 roulette phastcons_10-15
# 18 roulette phastcons_15-20
# 18 roulette phastcons_20-25
# 18 roulette phastcons_25-30
# 18 roulette phastcons_30-35
# 18 roulette phastcons_35-40
# 18 roulette phastcons_40-45
# 18 roulette phastcons_45-50
# 18 roulette phastcons_50-55
# 18 roulette phastcons_55-60
# 18 roulette phastcons_60-65
# 18 roulette phastcons_65-70
# 18 roulette phastcons_70-75
# 18 roulette phastcons_75-80
# 19 carlson ccds_merged
# 19 carlson promoters
# 19 carlson enhancers
# 19 carlson ccds_lof_d1
# 19 carlson ccds_lof_d2
# 19 carlson ccds_lof_d3
# 19 carlson ccds_lof_d4
# 19 carlson ccds_lof_d5
# 19 carlson ccds_lof_d6
# 19 carlson ccds_lof_d7
# 19 carlson ccds_lof_d8
# 19 carlson ccds_lof_d9
# 19 carlson ccds_lof_d10
# 19 carlson ccds_lof_d11
# 19 carlson phastcons_0-5
# 19 carlson phastcons_5-10
# 19 carlson phastcons_10-15
# 19 carlson phastcons_15-20
# 19 carlson phastcons_20-25
# 19 carlson phastcons_25-30
# 19 carlson phastcons_30-35
# 19 carlson phastcons_35-40
# 19 carlson phastcons_40-45
# 19 carlson phastcons_45-50
# 19 carlson phastcons_50-55
# 19 carlson phastcons_55-60
# 19 carlson phastcons_60-65
# 19 carlson phastcons_65-70
# 19 carlson phastcons_70-75
# 19 carlson phastcons_75-80
# 19 gnomad ccds_merged
# 19 gnomad promoters
# 19 gnomad enhancers
# 19 gnomad ccds_lof_d1
# 19 gnomad ccds_lof_d2
# 19 gnomad ccds_lof_d3
# 19 gnomad ccds_lof_d4
# 19 gnomad ccds_lof_d5
# 19 gnomad ccds_lof_d6
# 19 gnomad ccds_lof_d7
# 19 gnomad ccds_lof_d8
# 19 gnomad ccds_lof_d9
# 19 gnomad ccds_lof_d10
# 19 gnomad ccds_lof_d11
# 19 gnomad phastcons_0-5
# 19 gnomad phastcons_5-10
# 19 gnomad phastcons_10-15
# 19 gnomad phastcons_15-20
# 19 gnomad phastcons_20-25
# 19 gnomad phastcons_25-30
# 19 gnomad phastcons_30-35
# 19 gnomad phastcons_35-40
# 19 gnomad phastcons_40-45
# 19 gnomad phastcons_45-50
# 19 gnomad phastcons_50-55
# 19 gnomad phastcons_55-60
# 19 gnomad phastcons_60-65
# 19 gnomad phastcons_65-70
# 19 gnomad phastcons_70-75
# 19 gnomad phastcons_75-80
# 19 roulette ccds_merged
# 19 roulette promoters
# 19 roulette enhancers
# 19 roulette ccds_lof_d1
# 19 roulette ccds_lof_d2
# 19 roulette ccds_lof_d3
# 19 roulette ccds_lof_d4
# 19 roulette ccds_lof_d5
# 19 roulette ccds_lof_d6
# 19 roulette ccds_lof_d7
# 19 roulette ccds_lof_d8
# 19 roulette ccds_lof_d9
# 19 roulette ccds_lof_d10
# 19 roulette ccds_lof_d11
# 19 roulette phastcons_0-5
# 19 roulette phastcons_5-10
# 19 roulette phastcons_10-15
# 19 roulette phastcons_15-20
# 19 roulette phastcons_20-25
# 19 roulette phastcons_25-30
# 19 roulette phastcons_30-35
# 19 roulette phastcons_35-40
# 19 roulette phastcons_40-45
# 19 roulette phastcons_45-50
# 19 roulette phastcons_50-55
# 19 roulette phastcons_55-60
# 19 roulette phastcons_60-65
# 19 roulette phastcons_65-70
# 19 roulette phastcons_70-75
# 19 roulette phastcons_75-80
# 20 carlson ccds_merged
# 20 carlson promoters
# 20 carlson enhancers
# 20 carlson ccds_lof_d1
# 20 carlson ccds_lof_d2
# 20 carlson ccds_lof_d3
# 20 carlson ccds_lof_d4
# 20 carlson ccds_lof_d5
# 20 carlson ccds_lof_d6
# 20 carlson ccds_lof_d7
# 20 carlson ccds_lof_d8
# 20 carlson ccds_lof_d9
# 20 carlson ccds_lof_d10
# 20 carlson ccds_lof_d11
# 20 carlson phastcons_0-5
# 20 carlson phastcons_5-10
# 20 carlson phastcons_10-15
# 20 carlson phastcons_15-20
# 20 carlson phastcons_20-25
# 20 carlson phastcons_25-30
# 20 carlson phastcons_30-35
# 20 carlson phastcons_35-40
# 20 carlson phastcons_40-45
# 20 carlson phastcons_45-50
# 20 carlson phastcons_50-55
# 20 carlson phastcons_55-60
# 20 carlson phastcons_60-65
# 20 carlson phastcons_65-70
# 20 carlson phastcons_70-75
# 20 carlson phastcons_75-80
# 20 gnomad ccds_merged
# 20 gnomad promoters
# 20 gnomad enhancers
# 20 gnomad ccds_lof_d1
# 20 gnomad ccds_lof_d2
# 20 gnomad ccds_lof_d3
# 20 gnomad ccds_lof_d4
# 20 gnomad ccds_lof_d5
# 20 gnomad ccds_lof_d6
# 20 gnomad ccds_lof_d7
# 20 gnomad ccds_lof_d8
# 20 gnomad ccds_lof_d9
# 20 gnomad ccds_lof_d10
# 20 gnomad ccds_lof_d11
# 20 gnomad phastcons_0-5
# 20 gnomad phastcons_5-10
# 20 gnomad phastcons_10-15
# 20 gnomad phastcons_15-20
# 20 gnomad phastcons_20-25
# 20 gnomad phastcons_25-30
# 20 gnomad phastcons_30-35
# 20 gnomad phastcons_35-40
# 20 gnomad phastcons_40-45
# 20 gnomad phastcons_45-50
# 20 gnomad phastcons_50-55
# 20 gnomad phastcons_55-60
# 20 gnomad phastcons_60-65
# 20 gnomad phastcons_65-70
# 20 gnomad phastcons_70-75
# 20 gnomad phastcons_75-80
# 20 roulette ccds_merged
# 20 roulette promoters
# 20 roulette enhancers
# 20 roulette ccds_lof_d1
# 20 roulette ccds_lof_d2
# 20 roulette ccds_lof_d3
# 20 roulette ccds_lof_d4
# 20 roulette ccds_lof_d5
# 20 roulette ccds_lof_d6
# 20 roulette ccds_lof_d7
# 20 roulette ccds_lof_d8
# 20 roulette ccds_lof_d9
# 20 roulette ccds_lof_d10
# 20 roulette ccds_lof_d11
# 20 roulette phastcons_0-5
# 20 roulette phastcons_5-10
# 20 roulette phastcons_10-15
# 20 roulette phastcons_15-20
# 20 roulette phastcons_20-25
# 20 roulette phastcons_25-30
# 20 roulette phastcons_30-35
# 20 roulette phastcons_35-40
# 20 roulette phastcons_40-45
# 20 roulette phastcons_45-50
# 20 roulette phastcons_50-55
# 20 roulette phastcons_55-60
# 20 roulette phastcons_60-65
# 20 roulette phastcons_65-70
# 20 roulette phastcons_70-75
# 20 roulette phastcons_75-80
# 21 carlson ccds_merged
# 21 carlson promoters
# 21 carlson enhancers
# 21 carlson ccds_lof_d1
# 21 carlson ccds_lof_d2
# 21 carlson ccds_lof_d3
# 21 carlson ccds_lof_d4
# 21 carlson ccds_lof_d5
# 21 carlson ccds_lof_d6
# 21 carlson ccds_lof_d7
# 21 carlson ccds_lof_d8
# 21 carlson ccds_lof_d9
# 21 carlson ccds_lof_d10
# 21 carlson ccds_lof_d11
# 21 carlson phastcons_0-5
# 21 carlson phastcons_5-10
# 21 carlson phastcons_10-15
# 21 carlson phastcons_15-20
# 21 carlson phastcons_20-25
# 21 carlson phastcons_25-30
# 21 carlson phastcons_30-35
# 21 carlson phastcons_35-40
# 21 carlson phastcons_40-45
# 21 carlson phastcons_45-50
# 21 carlson phastcons_50-55
# 21 carlson phastcons_55-60
# 21 carlson phastcons_60-65
# 21 carlson phastcons_65-70
# 21 carlson phastcons_70-75
# 21 carlson phastcons_75-80
# 21 gnomad ccds_merged
# 21 gnomad promoters
# 21 gnomad enhancers
# 21 gnomad ccds_lof_d1
# 21 gnomad ccds_lof_d2
# 21 gnomad ccds_lof_d3
# 21 gnomad ccds_lof_d4
# 21 gnomad ccds_lof_d5
# 21 gnomad ccds_lof_d6
# 21 gnomad ccds_lof_d7
# 21 gnomad ccds_lof_d8
# 21 gnomad ccds_lof_d9
# 21 gnomad ccds_lof_d10
# 21 gnomad ccds_lof_d11
# 21 gnomad phastcons_0-5
# 21 gnomad phastcons_5-10
# 21 gnomad phastcons_10-15
# 21 gnomad phastcons_15-20
# 21 gnomad phastcons_20-25
# 21 gnomad phastcons_25-30
# 21 gnomad phastcons_30-35
# 21 gnomad phastcons_35-40
# 21 gnomad phastcons_40-45
# 21 gnomad phastcons_45-50
# 21 gnomad phastcons_50-55
# 21 gnomad phastcons_55-60
# 21 gnomad phastcons_60-65
# 21 gnomad phastcons_65-70
# 21 gnomad phastcons_70-75
# 21 gnomad phastcons_75-80
# 21 roulette ccds_merged
# 21 roulette promoters
# 21 roulette enhancers
# 21 roulette ccds_lof_d1
# 21 roulette ccds_lof_d2
# 21 roulette ccds_lof_d3
# 21 roulette ccds_lof_d4
# 21 roulette ccds_lof_d5
# 21 roulette ccds_lof_d6
# 21 roulette ccds_lof_d7
# 21 roulette ccds_lof_d8
# 21 roulette ccds_lof_d9
# 21 roulette ccds_lof_d10
# 21 roulette ccds_lof_d11
# 21 roulette phastcons_0-5
# 21 roulette phastcons_5-10
# 21 roulette phastcons_10-15
# 21 roulette phastcons_15-20
# 21 roulette phastcons_20-25
# 21 roulette phastcons_25-30
# 21 roulette phastcons_30-35
# 21 roulette phastcons_35-40
# 21 roulette phastcons_40-45
# 21 roulette phastcons_45-50
# 21 roulette phastcons_50-55
# 21 roulette phastcons_55-60
# 21 roulette phastcons_60-65
# 21 roulette phastcons_65-70
# 21 roulette phastcons_70-75
# 21 roulette phastcons_75-80
# 22 carlson ccds_merged
# 22 carlson promoters
# 22 carlson enhancers
# 22 carlson ccds_lof_d1
# 22 carlson ccds_lof_d2
# 22 carlson ccds_lof_d3
# 22 carlson ccds_lof_d4
# 22 carlson ccds_lof_d5
# 22 carlson ccds_lof_d6
# 22 carlson ccds_lof_d7
# 22 carlson ccds_lof_d8
# 22 carlson ccds_lof_d9
# 22 carlson ccds_lof_d10
# 22 carlson ccds_lof_d11
# 22 carlson phastcons_0-5
# 22 carlson phastcons_5-10
# 22 carlson phastcons_10-15
# 22 carlson phastcons_15-20
# 22 carlson phastcons_20-25
# 22 carlson phastcons_25-30
# 22 carlson phastcons_30-35
# 22 carlson phastcons_35-40
# 22 carlson phastcons_40-45
# 22 carlson phastcons_45-50
# 22 carlson phastcons_50-55
# 22 carlson phastcons_55-60
# 22 carlson phastcons_60-65
# 22 carlson phastcons_65-70
# 22 carlson phastcons_70-75
# 22 carlson phastcons_75-80
# 22 gnomad ccds_merged
# 22 gnomad promoters
# 22 gnomad enhancers
# 22 gnomad ccds_lof_d1
# 22 gnomad ccds_lof_d2
# 22 gnomad ccds_lof_d3
# 22 gnomad ccds_lof_d4
# 22 gnomad ccds_lof_d5
# 22 gnomad ccds_lof_d6
# 22 gnomad ccds_lof_d7
# 22 gnomad ccds_lof_d8
# 22 gnomad ccds_lof_d9
# 22 gnomad ccds_lof_d10
# 22 gnomad ccds_lof_d11
# 22 gnomad phastcons_0-5
# 22 gnomad phastcons_5-10
# 22 gnomad phastcons_10-15
# 22 gnomad phastcons_15-20
# 22 gnomad phastcons_20-25
# 22 gnomad phastcons_25-30
# 22 gnomad phastcons_30-35
# 22 gnomad phastcons_35-40
# 22 gnomad phastcons_40-45
# 22 gnomad phastcons_45-50
# 22 gnomad phastcons_50-55
# 22 gnomad phastcons_55-60
# 22 gnomad phastcons_60-65
# 22 gnomad phastcons_65-70
# 22 gnomad phastcons_70-75
# 22 gnomad phastcons_75-80
# 22 roulette ccds_merged
# 22 roulette promoters
# 22 roulette enhancers
# 22 roulette ccds_lof_d1
# 22 roulette ccds_lof_d2
# 22 roulette ccds_lof_d3
# 22 roulette ccds_lof_d4
# 22 roulette ccds_lof_d5
# 22 roulette ccds_lof_d6
# 22 roulette ccds_lof_d7
# 22 roulette ccds_lof_d8
# 22 roulette ccds_lof_d9
# 22 roulette ccds_lof_d10
# 22 roulette ccds_lof_d11
# 22 roulette phastcons_0-5
# 22 roulette phastcons_5-10
# 22 roulette phastcons_10-15
# 22 roulette phastcons_15-20
# 22 roulette phastcons_20-25
# 22 roulette phastcons_25-30
# 22 roulette phastcons_30-35
# 22 roulette phastcons_35-40
# 22 roulette phastcons_40-45
# 22 roulette phastcons_45-50
# 22 roulette phastcons_50-55
# 22 roulette phastcons_55-60
# 22 roulette phastcons_60-65
# 22 roulette phastcons_65-70
# 22 roulette phastcons_70-75
# 22 roulette phastcons_75-80
