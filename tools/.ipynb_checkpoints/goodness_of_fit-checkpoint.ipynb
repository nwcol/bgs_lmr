# %%
import numpy as np
import bgshr
import pandas
import scipy
import matplotlib.pyplot as plt

# %%
def apply_threshold(df, thresh):
    # drop all windows where df["num_sites"] < thresh
    df = df[df["num_sites"] >= thresh]
    return df

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "merged_cds_regulatory",
    "split_cds_regulatory",
    "merged_cds_phastcons",
    "split_cds_phastcons"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "chrom",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            for chrom in chroms:
                fname = f"../models/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                df = pandas.read_csv(fname)
                reduced_df = df.loc[:, cols_to_keep]
                row = [
                    cons_model,
                    mut_model,
                    chrom]
                for scale, thresh in zip(scales, threshs):
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    row += [
                        scipy.stats.pearsonr(scaled_df["B"], scaled_df["avg_pi"]).statistic ** 2,
                        scipy.stats.pearsonr(scaled_df["exp_pi"], scaled_df["avg_pi"]).statistic ** 2]
                data.append(row)
                print(cons_model, mut_model, chrom)
df = pandas.DataFrame(data, columns=cols)
df.to_csv("../models/R2_tbl.csv", index=False)
# Out:
# merged_cds_regulatory carlson 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 51
#      46 row = [
#      47     cons_model,
#      48     mut_model,
#      49     chrom]
#      50 for scale, thresh in zip(scales, threshs):
# ---> 51     scaled_df = bgshr.Util.scale_genome_table(df, scale)
#      52     scaled_df = apply_threshold(scaled_df, thresh)
#      53     row += [
#      54         scipy.stats.pearsonr(scaled_df["B"], scaled_df["avg_pi"]).statistic ** 2,
#      55         scipy.stats.pearsonr(scaled_df["exp_pi"], scaled_df["avg_pi"]).statistic ** 2]
#
# File ~/Projects/bgshr/bgshr/Util.py:1095, in scale_genome_table(df, scale)
#    1093     assert "del_sites" in df
#    1094     weights = np.array(df["del_sites"])
# -> 1095     data[col] = [weighted_avg(arr[mapping == i], weights[mapping == i])
#    1096         for i in idxs]
#    1098 elif col in ["neu_mut", "exp_neu_pi"]:
#    1099     assert "neu_sites" in df
#
# File ~/Projects/bgshr/bgshr/Util.py:1095, in <listcomp>(.0)
#    1093     assert "del_sites" in df
#    1094     weights = np.array(df["del_sites"])
# -> 1095     data[col] = [weighted_avg(arr[mapping == i], weights[mapping == i])
#    1096         for i in idxs]
#    1098 elif col in ["neu_mut", "exp_neu_pi"]:
#    1099     assert "neu_sites" in df
#
# File ~/Projects/bgshr/bgshr/Util.py:1045, in scale_genome_table.<locals>.weighted_avg(vals, weights)
#    1042         ret = np.mean(vals)
#    1043     return ret
# -> 1045 def weighted_avg(vals, weights):
#    1046     sum_weights = np.sum(weights)
#    1047     if sum_weights == 0:
#
# KeyboardInterrupt:

# %%
print(df.to_string(index=False))

# %%
print(df.to_string(index=False))
# Out:
#            cons_model mut_model  chrom  R^2_B,pi_10kb  R^2_Epi,pi_10kb  R^2_B,pi_100kb  R^2_Epi,pi_100kb  R^2_B,pi_1Mb  R^2_Epi,pi_1Mb
# merged_cds_regulatory   carlson      1       0.099729         0.101194        0.215124          0.216088      0.292978        0.319388
# merged_cds_regulatory   carlson      2       0.106793         0.089207        0.228008          0.194827      0.351966        0.292029
# merged_cds_regulatory   carlson      3       0.080673         0.084336        0.195053          0.200521      0.375899        0.374909
# merged_cds_regulatory   carlson      4       0.081076         0.078923        0.169673          0.164961      0.227792        0.241699
# merged_cds_regulatory   carlson      5       0.083925         0.075639        0.188246          0.165922      0.300924        0.256873
# merged_cds_regulatory   carlson      6       0.055717         0.069751        0.127132          0.152564      0.146780        0.213912
# merged_cds_regulatory   carlson      7       0.144776         0.145604        0.279774          0.302917      0.443419        0.499330
# merged_cds_regulatory   carlson      8       0.158663         0.138100        0.286486          0.267260      0.421531        0.385478
# merged_cds_regulatory   carlson      9       0.140128         0.131117        0.295931          0.277189      0.460919        0.424082
# merged_cds_regulatory   carlson     10       0.121164         0.113805        0.278516          0.265088      0.502648        0.484945
# merged_cds_regulatory   carlson     11       0.104633         0.108528        0.255796          0.263583      0.357650        0.363616
# merged_cds_regulatory   carlson     12       0.084008         0.087430        0.209480          0.210858      0.285113        0.284814
# merged_cds_regulatory   carlson     13       0.082789         0.066417        0.169193          0.135833      0.245223        0.164014
# merged_cds_regulatory   carlson     14       0.071379         0.064816        0.161205          0.143777      0.266758        0.234950
# merged_cds_regulatory   carlson     15       0.160177         0.182131        0.363940          0.402982      0.566043        0.618246
# merged_cds_regulatory   carlson     16       0.162634         0.185504        0.306461          0.350461      0.406177        0.476404
# merged_cds_regulatory   carlson     17       0.188838         0.210377        0.371461          0.415410      0.528032        0.607484
# merged_cds_regulatory   carlson     18       0.094276         0.071111        0.215640          0.174883      0.453359        0.369803
# merged_cds_regulatory   carlson     19       0.166092         0.104929        0.345520          0.279209      0.504471        0.425979
# merged_cds_regulatory   carlson     20       0.117630         0.126306        0.300343          0.313016      0.468004        0.497055
# merged_cds_regulatory   carlson     21       0.080768         0.061990        0.235661          0.209230      0.544159        0.464912
# merged_cds_regulatory   carlson     22       0.260319         0.277849        0.458310          0.498955      0.695579        0.720844
# merged_cds_regulatory    gnomad      1       0.099254         0.104333        0.208158          0.235297      0.269559        0.355400
# merged_cds_regulatory    gnomad      2       0.103718         0.112335        0.217540          0.267519      0.322616        0.427179
# merged_cds_regulatory    gnomad      3       0.083861         0.086126        0.193921          0.213997      0.344326        0.368403
#   split_cds_phastcons    gnomad     21       0.107825         0.123445        0.271359          0.303256      0.503664        0.555287
#   split_cds_phastcons    gnomad     22       0.361666         0.395745        0.619092          0.637317      0.771828        0.774904
#   split_cds_phastcons  roulette      1       0.186656         0.197294        0.379473          0.377211      0.584327        0.573033
#   split_cds_phastcons  roulette      2       0.165287         0.184505        0.346859          0.367047      0.502803        0.533939
#   split_cds_phastcons  roulette      3       0.148843         0.172650        0.323223          0.358214      0.525331        0.570019
#   split_cds_phastcons  roulette      4       0.121463         0.148413        0.267024          0.306965      0.404699        0.500729
#   split_cds_phastcons  roulette      5       0.147080         0.160595        0.300446          0.306894      0.459953        0.466765
#   split_cds_phastcons  roulette      6       0.139125         0.169353        0.314960          0.350105      0.517112        0.576975
#   split_cds_phastcons  roulette      7       0.221663         0.251818        0.430091          0.454943      0.628543        0.649109
#   split_cds_phastcons  roulette      8       0.231984         0.390816        0.391777          0.631680      0.532960        0.817619
#   split_cds_phastcons  roulette      9       0.196172         0.240048        0.367692          0.430984      0.502073        0.592112
#   split_cds_phastcons  roulette     10       0.181842         0.190932        0.396736          0.388781      0.659469        0.627995
#   split_cds_phastcons  roulette     11       0.170437         0.169547        0.377151          0.361042      0.568017        0.514692
#   split_cds_phastcons  roulette     12       0.157214         0.182431        0.350769          0.392112      0.535291        0.558047
#   split_cds_phastcons  roulette     13       0.121294         0.141934        0.251277          0.281034      0.315515        0.360949
#   split_cds_phastcons  roulette     14       0.124757         0.136584        0.264133          0.268603      0.394550        0.377081
#   split_cds_phastcons  roulette     15       0.230774         0.267374        0.479267          0.521298      0.699796        0.721630
#   split_cds_phastcons  roulette     16       0.229100         0.446974        0.406688          0.669087      0.537367        0.844975
#   split_cds_phastcons  roulette     17       0.245536         0.279057        0.490020          0.542261      0.656458        0.670885
#   split_cds_phastcons  roulette     18       0.161663         0.159630        0.360899          0.341325      0.685673        0.617764
#   split_cds_phastcons  roulette     19       0.175297         0.107112        0.386057          0.270949      0.567513        0.418177
#   split_cds_phastcons  roulette     20       0.170342         0.190575        0.401917          0.413838      0.631058        0.635153
#   split_cds_phastcons  roulette     21       0.107179         0.140172        0.271045          0.327004      0.502088        0.609927
#   split_cds_phastcons  roulette     22       0.359095         0.422789        0.615104          0.667756      0.768338        0.809287

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "merged_cds_regulatory",
    "split_cds_regulatory",
    "merged_cds_phastcons",
    "split_cds_phastcons"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            row = [
                cons_model,
                mut_model]
            for scale, thresh in zip(scales, threshs):
                scaled_dfs = []
                for chrom in chroms:
                    fname = f"../models/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                    df = pandas.read_csv(fname)
                    reduced_df = df.loc[:, cols_to_keep]
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    scaled_dfs.append(scaled_df)
                # concatenate tables from all autosomes
                concat_df = pandas.concat(scaled_dfs)
                row += [
                    scipy.stats.pearsonr(concat_df["B"], concat_df["avg_pi"]).statistic ** 2,
                    scipy.stats.pearsonr(concat_df["exp_pi"], concat_df["avg_pi"]).statistic ** 2]
                print(cons_model, mut_model, scale)
            data.append(row)
df = pandas.DataFrame(data, columns=cols)
df.to_csv("../models/autosome_wide_R2_tbl.csv", index=False)
print(df.to_string(index=False))
# Out:
# merged_cds_regulatory carlson 10000.0
# merged_cds_regulatory carlson 100000.0
# merged_cds_regulatory carlson 1000000.0
# merged_cds_regulatory gnomad 10000.0
# merged_cds_regulatory gnomad 100000.0
# merged_cds_regulatory gnomad 1000000.0
# merged_cds_regulatory roulette 10000.0
# merged_cds_regulatory roulette 100000.0
# merged_cds_regulatory roulette 1000000.0
# split_cds_regulatory carlson 10000.0
# split_cds_regulatory carlson 100000.0
# split_cds_regulatory carlson 1000000.0
# split_cds_regulatory gnomad 10000.0
# split_cds_regulatory gnomad 100000.0
# split_cds_regulatory gnomad 1000000.0
# split_cds_regulatory roulette 10000.0
# split_cds_regulatory roulette 100000.0
# split_cds_regulatory roulette 1000000.0
# merged_cds_phastcons carlson 10000.0
# merged_cds_phastcons carlson 100000.0
# merged_cds_phastcons carlson 1000000.0
# merged_cds_phastcons gnomad 10000.0
# merged_cds_phastcons gnomad 100000.0
# merged_cds_phastcons gnomad 1000000.0
# merged_cds_phastcons roulette 10000.0
# merged_cds_phastcons roulette 100000.0
# merged_cds_phastcons roulette 1000000.0
# split_cds_phastcons carlson 10000.0
# split_cds_phastcons carlson 100000.0
# split_cds_phastcons carlson 1000000.0
# split_cds_phastcons gnomad 10000.0
# split_cds_phastcons gnomad 100000.0
# split_cds_phastcons gnomad 1000000.0
# split_cds_phastcons roulette 10000.0
# split_cds_phastcons roulette 100000.0
# split_cds_phastcons roulette 1000000.0
#            cons_model mut_model  R^2_B,pi_10kb  R^2_Epi,pi_10kb  R^2_B,pi_100kb  R^2_Epi,pi_100kb  R^2_B,pi_1Mb  R^2_Epi,pi_1Mb
# merged_cds_regulatory   carlson       0.100939         0.109582        0.214426          0.239733      0.312607        0.374623
# merged_cds_regulatory    gnomad       0.096516         0.113176        0.198273          0.252292      0.267723        0.388601
# merged_cds_regulatory  roulette       0.095214         0.186144        0.195467          0.365286      0.264419        0.572250
#  split_cds_regulatory   carlson       0.100865         0.108999        0.214943          0.238671      0.318552        0.373652
#  split_cds_regulatory    gnomad       0.096751         0.109805        0.199765          0.244595      0.275629        0.376362
#  split_cds_regulatory  roulette       0.095820         0.185185        0.197649          0.362750      0.273880        0.568970
#  merged_cds_phastcons   carlson       0.168285         0.166070        0.351322          0.338304      0.519081        0.495412
#  merged_cds_phastcons    gnomad       0.177157         0.193739        0.361763          0.384078      0.520403        0.563092
#  merged_cds_phastcons  roulette       0.173960         0.221214        0.355993          0.423995      0.511998        0.624057
#   split_cds_phastcons   carlson       0.168223         0.166496        0.351149          0.338789      0.519895        0.495913
#   split_cds_phastcons    gnomad       0.177278         0.193439        0.362206          0.382997      0.523176        0.561103
#   split_cds_phastcons  roulette       0.173988         0.221406        0.356195          0.423959      0.514359        0.623860

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "split_cds",
    "merged_cds"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            row = [
                cons_model,
                mut_model]
            for scale, thresh in zip(scales, threshs):
                scaled_dfs = []
                for chrom in chroms:
                    fname = f"../models/tables_10kb/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                    df = pandas.read_csv(fname)
                    reduced_df = df.loc[:, cols_to_keep]
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    scaled_dfs.append(scaled_df)
                # concatenate tables from all autosomes
                concat_df = pandas.concat(scaled_dfs)
                row += [
                    scipy.stats.pearsonr(concat_df["B"], concat_df["avg_pi"]).statistic ** 2,
                    scipy.stats.pearsonr(concat_df["exp_pi"], concat_df["avg_pi"]).statistic ** 2]
                print(cons_model, mut_model, scale)
            data.append(row)
df = pandas.DataFrame(data, columns=cols)
#df.to_csv("../models/autosome_wide_R2_tbl.csv", index=False)
#print(df.to_string(index=False))
# Out:
# split_cds carlson 10000.0
# split_cds carlson 100000.0
# split_cds carlson 1000000.0
# split_cds gnomad 10000.0
# split_cds gnomad 100000.0
# split_cds gnomad 1000000.0
# split_cds roulette 10000.0
# split_cds roulette 100000.0
# split_cds roulette 1000000.0
# merged_cds carlson 10000.0
# merged_cds carlson 100000.0
# merged_cds carlson 1000000.0
# merged_cds gnomad 10000.0
# merged_cds gnomad 100000.0
# merged_cds gnomad 1000000.0
# merged_cds roulette 10000.0
# merged_cds roulette 100000.0
# merged_cds roulette 1000000.0
