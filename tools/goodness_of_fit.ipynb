# %%
import numpy as np
import bgshr
import pandas
import scipy
import matplotlib.pyplot as plt

# %%
def apply_threshold(df, thresh):
    # drop all windows where df["num_sites"] < thresh
    df = df[df["num_sites"] >= thresh]
    return df

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "merged_cds_regulatory",
    "split_cds_regulatory",
    "merged_cds_phastcons",
    "split_cds_phastcons"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "chrom",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            for chrom in chroms:
                fname = f"../models/tables_10kb/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                df = pandas.read_csv(fname)
                reduced_df = df.loc[:, cols_to_keep]
                row = [
                    cons_model,
                    mut_model,
                    chrom]
                for scale, thresh in zip(scales, threshs):
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    row += [
                        scipy.stats.pearsonr(scaled_df["B"], scaled_df["avg_pi"]).statistic ** 2,
                        scipy.stats.pearsonr(scaled_df["exp_pi"], scaled_df["avg_pi"]).statistic ** 2]
                data.append(row)
                print(cons_model, mut_model, chrom)
df = pandas.DataFrame(data, columns=cols)
df.to_csv("../models/R2_tbl.csv", index=False)
# Out:
# merged_cds_regulatory carlson 1
# merged_cds_regulatory carlson 2
# merged_cds_regulatory carlson 3
# merged_cds_regulatory carlson 4
# merged_cds_regulatory carlson 5
# merged_cds_regulatory carlson 6
# merged_cds_regulatory carlson 7
# merged_cds_regulatory carlson 8
# merged_cds_regulatory carlson 9
# merged_cds_regulatory carlson 10
# merged_cds_regulatory carlson 11
# merged_cds_regulatory carlson 12
# merged_cds_regulatory carlson 13
# merged_cds_regulatory carlson 14
# merged_cds_regulatory carlson 15
# merged_cds_regulatory carlson 16
# merged_cds_regulatory carlson 17
# merged_cds_regulatory carlson 18
# merged_cds_regulatory carlson 19
# merged_cds_regulatory carlson 20
# merged_cds_regulatory carlson 21
# merged_cds_regulatory carlson 22
# merged_cds_regulatory gnomad 1
# merged_cds_regulatory gnomad 2
# merged_cds_regulatory gnomad 3
# merged_cds_regulatory gnomad 4
# merged_cds_regulatory gnomad 5
# merged_cds_regulatory gnomad 6
# merged_cds_regulatory gnomad 7
# merged_cds_regulatory gnomad 8
# merged_cds_regulatory gnomad 9
# merged_cds_regulatory gnomad 10
# merged_cds_regulatory gnomad 11
# merged_cds_regulatory gnomad 12
# merged_cds_regulatory gnomad 13
# merged_cds_regulatory gnomad 14
# merged_cds_regulatory gnomad 15
# merged_cds_regulatory gnomad 16
# merged_cds_regulatory gnomad 17
# merged_cds_regulatory gnomad 18
# merged_cds_regulatory gnomad 19
# merged_cds_regulatory gnomad 20
# merged_cds_regulatory gnomad 21
# merged_cds_regulatory gnomad 22
# merged_cds_regulatory roulette 1
# merged_cds_regulatory roulette 2
# merged_cds_regulatory roulette 3
# merged_cds_regulatory roulette 4
# merged_cds_regulatory roulette 5
# merged_cds_regulatory roulette 6
# merged_cds_regulatory roulette 7
# merged_cds_regulatory roulette 8
# merged_cds_regulatory roulette 9
# merged_cds_regulatory roulette 10
# merged_cds_regulatory roulette 11
# merged_cds_regulatory roulette 12
# merged_cds_regulatory roulette 13
# merged_cds_regulatory roulette 14
# merged_cds_regulatory roulette 15
# merged_cds_regulatory roulette 16
# merged_cds_regulatory roulette 17
# merged_cds_regulatory roulette 18
# merged_cds_regulatory roulette 19
# merged_cds_regulatory roulette 20
# merged_cds_regulatory roulette 21
# merged_cds_regulatory roulette 22
# split_cds_regulatory carlson 1
# split_cds_regulatory carlson 2
# split_cds_regulatory carlson 3
# split_cds_regulatory carlson 4
# split_cds_regulatory carlson 5
# split_cds_regulatory carlson 6
# split_cds_regulatory carlson 7
# split_cds_regulatory carlson 8
# split_cds_regulatory carlson 9
# split_cds_regulatory carlson 10
# split_cds_regulatory carlson 11
# split_cds_regulatory carlson 12
# split_cds_regulatory carlson 13
# split_cds_regulatory carlson 14
# split_cds_regulatory carlson 15
# split_cds_regulatory carlson 16
# split_cds_regulatory carlson 17
# split_cds_regulatory carlson 18
# split_cds_regulatory carlson 19
# split_cds_regulatory carlson 20
# split_cds_regulatory carlson 21
# split_cds_regulatory carlson 22
# split_cds_regulatory gnomad 1
# split_cds_regulatory gnomad 2
# split_cds_regulatory gnomad 3
# split_cds_regulatory gnomad 4
# split_cds_regulatory gnomad 5
# split_cds_regulatory gnomad 6
# split_cds_regulatory gnomad 7
# split_cds_regulatory gnomad 8
# split_cds_regulatory gnomad 9
# split_cds_regulatory gnomad 10
# split_cds_regulatory gnomad 11
# split_cds_regulatory gnomad 12
# split_cds_regulatory gnomad 13
# split_cds_regulatory gnomad 14
# split_cds_regulatory gnomad 15
# split_cds_regulatory gnomad 16
# split_cds_regulatory gnomad 17
# split_cds_regulatory gnomad 18
# split_cds_regulatory gnomad 19
# split_cds_regulatory gnomad 20
# split_cds_regulatory gnomad 21
# split_cds_regulatory gnomad 22
# split_cds_regulatory roulette 1
# split_cds_regulatory roulette 2
# split_cds_regulatory roulette 3
# split_cds_regulatory roulette 4
# split_cds_regulatory roulette 5
# split_cds_regulatory roulette 6
# split_cds_regulatory roulette 7
# split_cds_regulatory roulette 8
# split_cds_regulatory roulette 9
# split_cds_regulatory roulette 10
# split_cds_regulatory roulette 11
# split_cds_regulatory roulette 12
# split_cds_regulatory roulette 13
# split_cds_regulatory roulette 14
# split_cds_regulatory roulette 15
# split_cds_regulatory roulette 16
# split_cds_regulatory roulette 17
# split_cds_regulatory roulette 18
# split_cds_regulatory roulette 19
# split_cds_regulatory roulette 20
# split_cds_regulatory roulette 21
# split_cds_regulatory roulette 22
# merged_cds_phastcons carlson 1
# merged_cds_phastcons carlson 2
# merged_cds_phastcons carlson 3
# merged_cds_phastcons carlson 4
# merged_cds_phastcons carlson 5
# merged_cds_phastcons carlson 6
# merged_cds_phastcons carlson 7
# merged_cds_phastcons carlson 8
# merged_cds_phastcons carlson 9
# merged_cds_phastcons carlson 10
# merged_cds_phastcons carlson 11
# merged_cds_phastcons carlson 12
# merged_cds_phastcons carlson 13
# merged_cds_phastcons carlson 14
# merged_cds_phastcons carlson 15
# merged_cds_phastcons carlson 16
# merged_cds_phastcons carlson 17
# merged_cds_phastcons carlson 18
# merged_cds_phastcons carlson 19
# merged_cds_phastcons carlson 20
# merged_cds_phastcons carlson 21
# merged_cds_phastcons carlson 22
# merged_cds_phastcons gnomad 1
# merged_cds_phastcons gnomad 2
# merged_cds_phastcons gnomad 3
# merged_cds_phastcons gnomad 4
# merged_cds_phastcons gnomad 5
# merged_cds_phastcons gnomad 6
# merged_cds_phastcons gnomad 7
# merged_cds_phastcons gnomad 8
# merged_cds_phastcons gnomad 9
# merged_cds_phastcons gnomad 10
# merged_cds_phastcons gnomad 11
# merged_cds_phastcons gnomad 12
# merged_cds_phastcons gnomad 13
# merged_cds_phastcons gnomad 14
# merged_cds_phastcons gnomad 15
# merged_cds_phastcons gnomad 16
# merged_cds_phastcons gnomad 17
# merged_cds_phastcons gnomad 18
# merged_cds_phastcons gnomad 19
# merged_cds_phastcons gnomad 20
# merged_cds_phastcons gnomad 21
# merged_cds_phastcons gnomad 22
# merged_cds_phastcons roulette 1
# merged_cds_phastcons roulette 2
# merged_cds_phastcons roulette 3
# merged_cds_phastcons roulette 4
# merged_cds_phastcons roulette 5
# merged_cds_phastcons roulette 6
# merged_cds_phastcons roulette 7
# merged_cds_phastcons roulette 8
# merged_cds_phastcons roulette 9
# merged_cds_phastcons roulette 10
# merged_cds_phastcons roulette 11
# merged_cds_phastcons roulette 12
# merged_cds_phastcons roulette 13
# merged_cds_phastcons roulette 14
# merged_cds_phastcons roulette 15
# merged_cds_phastcons roulette 16
# merged_cds_phastcons roulette 17
# merged_cds_phastcons roulette 18
# merged_cds_phastcons roulette 19
# merged_cds_phastcons roulette 20
# merged_cds_phastcons roulette 21
# merged_cds_phastcons roulette 22
# split_cds_phastcons carlson 1
# split_cds_phastcons carlson 2
# split_cds_phastcons carlson 3
# split_cds_phastcons carlson 4
# split_cds_phastcons carlson 5
# split_cds_phastcons carlson 6
# split_cds_phastcons carlson 7
# split_cds_phastcons carlson 8
# split_cds_phastcons carlson 9
# split_cds_phastcons carlson 10
# split_cds_phastcons carlson 11
# split_cds_phastcons carlson 12
# split_cds_phastcons carlson 13
# split_cds_phastcons carlson 14
# split_cds_phastcons carlson 15
# split_cds_phastcons carlson 16
# split_cds_phastcons carlson 17
# split_cds_phastcons carlson 18
# split_cds_phastcons carlson 19
# split_cds_phastcons carlson 20
# split_cds_phastcons carlson 21
# split_cds_phastcons carlson 22
# split_cds_phastcons gnomad 1
# split_cds_phastcons gnomad 2
# split_cds_phastcons gnomad 3
# split_cds_phastcons gnomad 4
# split_cds_phastcons gnomad 5
# split_cds_phastcons gnomad 6
# split_cds_phastcons gnomad 7
# split_cds_phastcons gnomad 8
# split_cds_phastcons gnomad 9
# split_cds_phastcons gnomad 10
# split_cds_phastcons gnomad 11
# split_cds_phastcons gnomad 12
# split_cds_phastcons gnomad 13
# split_cds_phastcons gnomad 14
# split_cds_phastcons gnomad 15
# split_cds_phastcons gnomad 16
# split_cds_phastcons gnomad 17
# split_cds_phastcons gnomad 18
# split_cds_phastcons gnomad 19
# split_cds_phastcons gnomad 20
# split_cds_phastcons gnomad 21
# split_cds_phastcons gnomad 22
# split_cds_phastcons roulette 1
# split_cds_phastcons roulette 2
# split_cds_phastcons roulette 3
# split_cds_phastcons roulette 4
# split_cds_phastcons roulette 5
# split_cds_phastcons roulette 6
# split_cds_phastcons roulette 7
# split_cds_phastcons roulette 8
# split_cds_phastcons roulette 9
# split_cds_phastcons roulette 10
# split_cds_phastcons roulette 11
# split_cds_phastcons roulette 12
# split_cds_phastcons roulette 13
# split_cds_phastcons roulette 14
# split_cds_phastcons roulette 15
# split_cds_phastcons roulette 16
# split_cds_phastcons roulette 17
# split_cds_phastcons roulette 18
# split_cds_phastcons roulette 19
# split_cds_phastcons roulette 20
# split_cds_phastcons roulette 21
# split_cds_phastcons roulette 22

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "merged_cds_regulatory",
    "split_cds_regulatory",
    "merged_cds_phastcons",
    "split_cds_phastcons"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            row = [
                cons_model,
                mut_model]
            for scale, thresh in zip(scales, threshs):
                scaled_dfs = []
                for chrom in chroms:
                    fname = f"../models/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                    df = pandas.read_csv(fname)
                    reduced_df = df.loc[:, cols_to_keep]
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    scaled_dfs.append(scaled_df)
                # concatenate tables from all autosomes
                concat_df = pandas.concat(scaled_dfs)
                row += [
                    scipy.stats.pearsonr(concat_df["B"], concat_df["avg_pi"]).statistic ** 2,
                    scipy.stats.pearsonr(concat_df["exp_pi"], concat_df["avg_pi"]).statistic ** 2]
                print(cons_model, mut_model, scale)
            data.append(row)
df = pandas.DataFrame(data, columns=cols)
df.to_csv("../models/autosomal_R2_tbl.csv", index=False)
print(df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 48
#      46 for chrom in chroms:
#      47     fname = f"../models/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
# ---> 48     df = pandas.read_csv(fname)
#      49     reduced_df = df.loc[:, cols_to_keep]
#      50     scaled_df = bgshr.Util.scale_genome_table(df, scale)
#
# File ~/venvs/bgshr_local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/venvs/bgshr_local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/venvs/bgshr_local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/venvs/bgshr_local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/venvs/bgshr_local/lib/python3.11/site-packages/pandas/io/common.py:809, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     805 if compression == "gzip":
#     806     if isinstance(handle, str):
#     807         # error: Incompatible types in assignment (expression has type
#     808         # "GzipFile", variable has type "Union[str, BaseBuffer]")
# --> 809         handle = gzip.GzipFile(  # type: ignore[assignment]
#     810             filename=handle,
#     811             mode=ioargs.mode,
#     812             **compression_args,
#     813         )
#     814     else:
#     815         handle = gzip.GzipFile(
#     816             # No overload variant of "GzipFile" matches argument types
#     817             # "Union[str, BaseBuffer]", "str", "Dict[str, Any]"
#    (...)    820             **compression_args,
#     821         )
#
# File /usr/lib/python3.11/gzip.py:174, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172     mode += 'b'
#     173 if fileobj is None:
# --> 174     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175 if filename is None:
#     176     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/equilibrium_granular_Ne/merged_cds_regulatory/carlson/B_tbl_YRI_chr1_10kb.csv.gz'

# %%
demographies = [
    "equilibrium_granular_Ne"]
cons_models = [
    "split_cds",
    "merged_cds"]
mut_models = [
    "carlson",
    "gnomad",
    "roulette"]
chroms = list(range(1, 23))
scales = [1e4, 1e5, 1e6]
threshs = [7_500, 50_000, 250_000]

cols = [
    "cons_model",
    "mut_model",
    "R^2_B,pi_10kb",
    "R^2_Epi,pi_10kb",
    "R^2_B,pi_100kb",
    "R^2_Epi,pi_100kb",
    "R^2_B,pi_1Mb",
    "R^2_Epi,pi_1Mb",
]
data = []

cols_to_keep = [
    "chrom", 
    "chromStart", 
    "chromEnd",
    "num_sites",
    "B",
    "exp_pi",
    "avg_pi"
]

for demography in demographies:
    for cons_model in cons_models:
        for mut_model in mut_models:
            row = [
                cons_model,
                mut_model]
            for scale, thresh in zip(scales, threshs):
                scaled_dfs = []
                for chrom in chroms:
                    fname = f"../models/tables_10kb/{demography}/{cons_model}/{mut_model}/B_tbl_YRI_chr{chrom}_10kb.csv.gz"
                    df = pandas.read_csv(fname)
                    reduced_df = df.loc[:, cols_to_keep]
                    scaled_df = bgshr.Util.scale_genome_table(df, scale)
                    scaled_df = apply_threshold(scaled_df, thresh)
                    scaled_dfs.append(scaled_df)
                # concatenate tables from all autosomes
                concat_df = pandas.concat(scaled_dfs)
                row += [
                    scipy.stats.pearsonr(concat_df["B"], concat_df["avg_pi"]).statistic ** 2,
                    scipy.stats.pearsonr(concat_df["exp_pi"], concat_df["avg_pi"]).statistic ** 2]
                print(cons_model, mut_model, scale)
            data.append(row)
df = pandas.DataFrame(data, columns=cols)
#df.to_csv("../models/autosome_wide_R2_tbl.csv", index=False)
#print(df.to_string(index=False))
# Out:
# split_cds carlson 10000.0
# split_cds carlson 100000.0
# split_cds carlson 1000000.0
# split_cds gnomad 10000.0
# split_cds gnomad 100000.0
# split_cds gnomad 1000000.0
# split_cds roulette 10000.0
# split_cds roulette 100000.0
# split_cds roulette 1000000.0
# merged_cds carlson 10000.0
# merged_cds carlson 100000.0
# merged_cds carlson 1000000.0
# merged_cds gnomad 10000.0
# merged_cds gnomad 100000.0
# merged_cds gnomad 1000000.0
# merged_cds roulette 10000.0
# merged_cds roulette 100000.0
# merged_cds roulette 1000000.0
